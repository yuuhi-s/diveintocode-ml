# %% [markdown]
# # Sprint18課題 公開されている実装を動かす

# %% [markdown]
# ## この課題の目的
#
# - 公開されている実装を動かす際のノウハウを得る
# - 論文で読んだ手法を動かしてみる

# %% [markdown]
# ## Faster R-CNN
#
# Sprint16で読んだFaster R-CNN\[1\]の実装を動かします。
#
# \[1\]Ren, S., He, K., Girshick, R., Sun, J.: Faster r-cnn: Towards real-time object detection with region proposal networks. In: Advances in neural information processing systems. (2015) 91–99
#
# [https://arxiv.org/pdf/1506.01497.pdf](https://arxiv.org/pdf/1506.01497.pdf)
#
# 以下のものを使用してください。Kerasを使用した実装です。
#
# [duckrabbits/ObjectDetection at master](https://github.com/duckrabbits/ObjectDetection/tree/master)

# %% [markdown]
# ## 【問題1】学習と推定
#
# READMEを参考に上記実装を動かしてください。

# %%
#学習
# %run train.py -p annotation.txt
# Out:
# Parsing annotation files
# Training images per class (19 classes) :
# {'abraham_grampa_simpson': 687,
#  'apu_nahasapeemapetilon': 206,
#  'bart_simpson': 650,
#  'bg': 0,
#  'charles_montgomery_burns': 650,
#  'chief_wiggum': 209,
#  'comic_book_guy': 208,
#  'edna_krabappel': 212,
#  'homer_simpson': 718,
#  'kent_brockman': 213,
#  'krusty_the_clown': 429,
#  'lisa_simpson': 756,
#  'marge_simpson': 629,
#  'milhouse_van_houten': 210,
#  'moe_szyslak': 403,
#  'ned_flanders': 675,
#  'nelson_muntz': 219,
#  'principal_skinner': 614,
#  'sideshow_bob': 201}
# -------------------------------
# path to config file : ./save/train_20190611-024351_config.pickle
# -------------------------------
# Epoch 1/100
# 100/100 [==============================] - 99s 988ms/step - rpn_cls: 4.3578 - rpn_regr: 0.1439 - detector_cls: 4.4108 - detector_regr: 2.9568
# Average number of overlapping bounding boxes from RPN = 19.01 for 100 previous iterations
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.059405940594058
# Classifier accuracy for bounding boxes from RPN: 0.5175
# Loss RPN classifier: 3.016015336487548
# Loss RPN regression: 0.13008021619170904
# Loss Detector classifier: 2.97722406797111
# Loss Detector regression: 1.4425767044723035
# Elapsed time: 99.36523294448853[s]
# Total loss decreased from inf to 7.5658963251226705, saving weights
# Epoch 2/100
#  99/100 [============================>.] - ETA: 0s - rpn_cls: 1.5456 - rpn_regr: 0.1255 - detector_cls: 2.1467 - detector_regr: 0.4973Average number of overlapping bounding boxes from RPN = 20.82 for 100 previous iterations
# 100/100 [==============================] - 61s 613ms/step - rpn_cls: 1.5464 - rpn_regr: 0.1255 - detector_cls: 2.1463 - detector_regr: 0.4974
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.821782178217823
# Classifier accuracy for bounding boxes from RPN: 0.515
# Loss RPN classifier: 1.6286499998449204
# Loss RPN regression: 0.12656783792655915
# Loss Detector classifier: 2.1058117604255675
# Loss Detector regression: 0.5100808718800545
# Elapsed time: 102.66034388542175[s]
# Total loss decreased from 7.5658963251226705 to 4.3711104700771015, saving weights
# Epoch 3/100
#  98/100 [============================>.] - ETA: 1s - rpn_cls: 1.7026 - rpn_regr: 0.1278 - detector_cls: 2.1394 - detector_regr: 0.4770Average number of overlapping bounding boxes from RPN = 19.75 for 100 previous iterations
# 100/100 [==============================] - 51s 514ms/step - rpn_cls: 1.7091 - rpn_regr: 0.1276 - detector_cls: 2.1391 - detector_regr: 0.4767
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.623762376237625
# Classifier accuracy for bounding boxes from RPN: 0.54
# Loss RPN classifier: 2.084265506545175
# Loss RPN regression: 0.12085069196298719
# Loss Detector classifier: 2.121979857683182
# Loss Detector regression: 0.463784269541502
# Elapsed time: 52.93096995353699[s]
# Epoch 4/100
#  20/100 [=====>........................] - ETA: 49s - rpn_cls: 2.4483 - rpn_regr: 0.1004 - detector_cls: 2.3444 - detector_regr: 0.4307Exception: 'NoneType' object is not subscriptable
#  39/100 [==========>...................] - ETA: 38s - rpn_cls: 2.4653 - rpn_regr: 0.1040 - detector_cls: 2.2780 - detector_regr: 0.4228Exception: 'NoneType' object is not subscriptable
#  70/100 [====================>.........] - ETA: 19s - rpn_cls: 2.3660 - rpn_regr: 0.1048 - detector_cls: 2.2352 - detector_regr: 0.4383Exception: 'NoneType' object is not subscriptable
#  97/100 [============================>.] - ETA: 1s - rpn_cls: 2.3046 - rpn_regr: 0.1060 - detector_cls: 2.2071 - detector_regr: 0.4448Average number of overlapping bounding boxes from RPN = 19.09 for 100 previous iterations
# 100/100 [==============================] - 65s 646ms/step - rpn_cls: 2.3003 - rpn_regr: 0.1060 - detector_cls: 2.2040 - detector_regr: 0.4450
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.485148514851485
# Classifier accuracy for bounding boxes from RPN: 0.5325
# Loss RPN classifier: 2.2058932150120993
# Loss RPN regression: 0.10514700497500598
# Loss Detector classifier: 2.096428345441818
# Loss Detector regression: 0.45079840913414954
# Elapsed time: 65.22488713264465[s]
# Epoch 5/100
#  96/100 [===========================>..] - ETA: 2s - rpn_cls: 3.1385 - rpn_regr: 0.1062 - detector_cls: 2.1136 - detector_regr: 0.4816Average number of overlapping bounding boxes from RPN = 17.34 for 100 previous iterations
# 100/100 [==============================] - 71s 709ms/step - rpn_cls: 3.1283 - rpn_regr: 0.1063 - detector_cls: 2.1118 - detector_regr: 0.4814
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.02970297029703
# Classifier accuracy for bounding boxes from RPN: 0.54
# Loss RPN classifier: 2.8406632023221117
# Loss RPN regression: 0.10931788075715304
# Loss Detector classifier: 2.0663057193160057
# Loss Detector regression: 0.476641169115901
# Elapsed time: 71.35034799575806[s]
# Epoch 6/100
#  95/100 [===========================>..] - ETA: 2s - rpn_cls: 1.7722 - rpn_regr: 0.1258 - detector_cls: 2.0720 - detector_regr: 0.4431Average number of overlapping bounding boxes from RPN = 20.76 for 100 previous iterations
# 100/100 [==============================] - 53s 530ms/step - rpn_cls: 1.7814 - rpn_regr: 0.1257 - detector_cls: 2.0717 - detector_regr: 0.4448
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.554455445544555
# Classifier accuracy for bounding boxes from RPN: 0.52
# Loss RPN classifier: 2.0872589153383103
# Loss RPN regression: 0.12457860969007015
# Loss Detector classifier: 2.0672661045193674
# Loss Detector regression: 0.4781147404015064
# Elapsed time: 53.53961658477783[s]
# Epoch 7/100
#   3/100 [..............................] - ETA: 49s - rpn_cls: 1.6775 - rpn_regr: 0.0665 - detector_cls: 1.9290 - detector_regr: 0.3703   Exception: 'NoneType' object is not subscriptable
#  94/100 [===========================>..] - ETA: 3s - rpn_cls: 2.3565 - rpn_regr: 0.0990 - detector_cls: 1.9329 - detector_regr: 0.4338Average number of overlapping bounding boxes from RPN = 20.56 for 100 previous iterations
# 100/100 [==============================] - 60s 601ms/step - rpn_cls: 2.3596 - rpn_regr: 0.0995 - detector_cls: 1.9350 - detector_regr: 0.4336
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.168316831683168
# Classifier accuracy for bounding boxes from RPN: 0.5425
# Loss RPN classifier: 2.4843572871678146
# Loss RPN regression: 0.10880253053270281
# Loss Detector classifier: 1.9748071360588073
# Loss Detector regression: 0.42801546975970267
# Elapsed time: 60.54598593711853[s]
# Epoch 8/100
#  93/100 [==========================>...] - ETA: 3s - rpn_cls: 1.2537 - rpn_regr: 0.1023 - detector_cls: 2.1094 - detector_regr: 0.4828Average number of overlapping bounding boxes from RPN = 24.01 for 100 previous iterations
# 100/100 [==============================] - 54s 537ms/step - rpn_cls: 1.2786 - rpn_regr: 0.1021 - detector_cls: 2.1079 - detector_regr: 0.4834
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 24.02970297029703
# Classifier accuracy for bounding boxes from RPN: 0.505
# Loss RPN classifier: 1.5933648546253198
# Loss RPN regression: 0.09913294337689876
# Loss Detector classifier: 2.0853676563501358
# Loss Detector regression: 0.48856964021921157
# Elapsed time: 54.27022671699524[s]
# Total loss decreased from 4.3711104700771015 to 4.266435094571566, saving weights
# Epoch 9/100
#  22/100 [=====>........................] - ETA: 45s - rpn_cls: 2.7408 - rpn_regr: 0.1047 - detector_cls: 1.7692 - detector_regr: 0.5241Exception: 'NoneType' object is not subscriptable
#  69/100 [===================>..........] - ETA: 17s - rpn_cls: 2.4754 - rpn_regr: 0.1112 - detector_cls: 1.8978 - detector_regr: 0.4518Exception: 'NoneType' object is not subscriptable
#  92/100 [==========================>...] - ETA: 4s - rpn_cls: 2.4730 - rpn_regr: 0.1151 - detector_cls: 1.9157 - detector_regr: 0.4462Average number of overlapping bounding boxes from RPN = 21.23 for 100 previous iterations
# 100/100 [==============================] - 55s 553ms/step - rpn_cls: 2.4653 - rpn_regr: 0.1160 - detector_cls: 1.9194 - detector_regr: 0.4452
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.425742574257427
# Classifier accuracy for bounding boxes from RPN: 0.54
# Loss RPN classifier: 2.2927051613003515
# Loss RPN regression: 0.1272363249771297
# Loss Detector classifier: 1.9674457201361657
# Loss Detector regression: 0.4333750793337822
# Elapsed time: 56.46821427345276[s]
# Epoch 10/100
#  25/100 [======>.......................] - ETA: 40s - rpn_cls: 1.2188 - rpn_regr: 0.1196 - detector_cls: 2.2404 - detector_regr: 0.4098Exception: 'NoneType' object is not subscriptable
#  91/100 [==========================>...] - ETA: 4s - rpn_cls: 1.4266 - rpn_regr: 0.1147 - detector_cls: 2.0987 - detector_regr: 0.4070Average number of overlapping bounding boxes from RPN = 22.61 for 100 previous iterations
# 100/100 [==============================] - 53s 526ms/step - rpn_cls: 1.4164 - rpn_regr: 0.1144 - detector_cls: 2.0937 - detector_regr: 0.4071
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.178217821782177
# Classifier accuracy for bounding boxes from RPN: 0.5225
# Loss RPN classifier: 1.2741822882939353
# Loss RPN regression: 0.11121334386989475
# Loss Detector classifier: 2.045530782416463
# Loss Detector regression: 0.40610433742403984
# Elapsed time: 53.0692822933197[s]
# Total loss decreased from 4.266435094571566 to 3.837030752004333, saving weights
# Epoch 11/100
#  66/100 [==================>...........] - ETA: 21s - rpn_cls: 1.1859 - rpn_regr: 0.1289 - detector_cls: 2.1058 - detector_regr: 0.5125Exception: 'NoneType' object is not subscriptable
#  90/100 [==========================>...] - ETA: 6s - rpn_cls: 1.2918 - rpn_regr: 0.1333 - detector_cls: 2.0818 - detector_regr: 0.5030Average number of overlapping bounding boxes from RPN = 21.47 for 100 previous iterations
# 100/100 [==============================] - 60s 600ms/step - rpn_cls: 1.3141 - rpn_regr: 0.1339 - detector_cls: 2.0750 - detector_regr: 0.4994
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.495049504950494
# Classifier accuracy for bounding boxes from RPN: 0.52
# Loss RPN classifier: 1.469008604477721
# Loss RPN regression: 0.13759460259228945
# Loss Detector classifier: 2.0104454002925194
# Loss Detector regression: 0.464661191701889
# Elapsed time: 61.210710763931274[s]
# Epoch 12/100
#  89/100 [=========================>....] - ETA: 6s - rpn_cls: 0.9647 - rpn_regr: 0.1340 - detector_cls: 2.1373 - detector_regr: 0.4917Average number of overlapping bounding boxes from RPN = 22.23 for 100 previous iterations
# 100/100 [==============================] - 55s 547ms/step - rpn_cls: 0.9670 - rpn_regr: 0.1347 - detector_cls: 2.1308 - detector_regr: 0.4896
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.594059405940595
# Classifier accuracy for bounding boxes from RPN: 0.505
# Loss RPN classifier: 0.9623042839379327
# Loss RPN regression: 0.1399676287267357
# Loss Detector classifier: 2.0746928095817565
# Loss Detector regression: 0.4695646135509014
# Elapsed time: 55.21110391616821[s]
# Total loss decreased from 3.837030752004333 to 3.646529335797326, saving weights
# Epoch 13/100
#  37/100 [==========>...................] - ETA: 33s - rpn_cls: 0.9915 - rpn_regr: 0.1421 - detector_cls: 2.0468 - detector_regr: 0.4870Exception: 'NoneType' object is not subscriptable
#  64/100 [==================>...........] - ETA: 19s - rpn_cls: 1.1540 - rpn_regr: 0.1579 - detector_cls: 2.0456 - detector_regr: 0.4833Exception: 'NoneType' object is not subscriptable
#  88/100 [=========================>....] - ETA: 6s - rpn_cls: 1.2722 - rpn_regr: 0.1584 - detector_cls: 2.0330 - detector_regr: 0.4804Average number of overlapping bounding boxes from RPN = 19.83 for 100 previous iterations
# 100/100 [==============================] - 55s 550ms/step - rpn_cls: 1.3366 - rpn_regr: 0.1574 - detector_cls: 2.0316 - detector_regr: 0.4781
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 18.465346534653467
# Classifier accuracy for bounding boxes from RPN: 0.54
# Loss RPN classifier: 1.8608699821990031
# Loss RPN regression: 0.15453575579449536
# Loss Detector classifier: 2.022581877708435
# Loss Detector regression: 0.45819644168019297
# Elapsed time: 56.22906565666199[s]
# Epoch 14/100
#  42/100 [===========>..................] - ETA: 34s - rpn_cls: 2.5806 - rpn_regr: 0.1207 - detector_cls: 2.0016 - detector_regr: 0.4543Exception: 'NoneType' object is not subscriptable
#  53/100 [==============>...............] - ETA: 27s - rpn_cls: 2.5800 - rpn_regr: 0.1223 - detector_cls: 2.0178 - detector_regr: 0.4597Exception: 'NoneType' object is not subscriptable
#  74/100 [=====================>........] - ETA: 15s - rpn_cls: 2.5363 - rpn_regr: 0.1239 - detector_cls: 2.0294 - detector_regr: 0.4631Exception: 'NoneType' object is not subscriptable
#  87/100 [=========================>....] - ETA: 7s - rpn_cls: 2.4917 - rpn_regr: 0.1249 - detector_cls: 2.0327 - detector_regr: 0.4639Average number of overlapping bounding boxes from RPN = 19.06 for 100 previous iterations
#  94/100 [===========================>..] - ETA: 3s - rpn_cls: 2.4612 - rpn_regr: 0.1252 - detector_cls: 2.0341 - detector_regr: 0.4645Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 57s 571ms/step - rpn_cls: 2.4322 - rpn_regr: 0.1254 - detector_cls: 2.0348 - detector_regr: 0.4650
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.396039603960396
# Classifier accuracy for bounding boxes from RPN: 0.52
# Loss RPN classifier: 1.9712252923954037
# Loss RPN regression: 0.12964163564145564
# Loss Detector classifier: 2.0448126864433287
# Loss Detector regression: 0.4736801469326019
# Elapsed time: 57.59235119819641[s]
# Epoch 15/100
#  86/100 [========================>.....] - ETA: 8s - rpn_cls: 1.8323 - rpn_regr: 0.1078 - detector_cls: 1.9266 - detector_regr: 0.3908Average number of overlapping bounding boxes from RPN = 21.57 for 100 previous iterations
# 100/100 [==============================] - 59s 594ms/step - rpn_cls: 1.8830 - rpn_regr: 0.1096 - detector_cls: 1.9238 - detector_regr: 0.3969
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.564356435643564
# Classifier accuracy for bounding boxes from RPN: 0.5375
# Loss RPN classifier: 2.222131033758511
# Loss RPN regression: 0.1194189871288836
# Loss Detector classifier: 1.9138291653990747
# Loss Detector regression: 0.4359898169338703
# Elapsed time: 61.85533690452576[s]
# Epoch 16/100
#  85/100 [========================>.....] - ETA: 7s - rpn_cls: 2.0339 - rpn_regr: 0.1197 - detector_cls: 1.8548 - detector_regr: 0.3609Average number of overlapping bounding boxes from RPN = 19.66 for 100 previous iterations
# 100/100 [==============================] - 52s 518ms/step - rpn_cls: 2.0085 - rpn_regr: 0.1200 - detector_cls: 1.8647 - detector_regr: 0.3670
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.900990099009903
# Classifier accuracy for bounding boxes from RPN: 0.535
# Loss RPN classifier: 1.8015387477448885
# Loss RPN regression: 0.11926734345965087
# Loss Detector classifier: 1.931020359992981
# Loss Detector regression: 0.4012643276900053
# Elapsed time: 52.26161813735962[s]
# Epoch 17/100
#  69/100 [===================>..........] - ETA: 17s - rpn_cls: 2.3483 - rpn_regr: 0.0779 - detector_cls: 1.9241 - detector_regr: 0.4536Exception: 'NoneType' object is not subscriptable
#  84/100 [========================>.....] - ETA: 8s - rpn_cls: 2.3080 - rpn_regr: 0.0807 - detector_cls: 1.9048 - detector_regr: 0.4524Average number of overlapping bounding boxes from RPN = 22.61 for 100 previous iterations
# 100/100 [==============================] - 57s 566ms/step - rpn_cls: 2.2885 - rpn_regr: 0.0834 - detector_cls: 1.8889 - detector_regr: 0.4515
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.019801980198018
# Classifier accuracy for bounding boxes from RPN: 0.535
# Loss RPN classifier: 2.200962511101041
# Loss RPN regression: 0.0973277719411999
# Loss Detector classifier: 1.802428929209709
# Loss Detector regression: 0.4480722402781248
# Elapsed time: 57.12182426452637[s]
# Epoch 18/100
#   2/100 [..............................] - ETA: 54s - rpn_cls: 4.5316 - rpn_regr: 0.0246 - detector_cls: 1.6830 - detector_regr: 0.2987Exception: 'NoneType' object is not subscriptable
#  83/100 [=======================>......] - ETA: 8s - rpn_cls: 1.7400 - rpn_regr: 0.0816 - detector_cls: 1.7533 - detector_regr: 0.4556Average number of overlapping bounding boxes from RPN = 22.13 for 100 previous iterations
# 100/100 [==============================] - 52s 522ms/step - rpn_cls: 1.8023 - rpn_regr: 0.0831 - detector_cls: 1.7542 - detector_regr: 0.4628
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.653465346534652
# Classifier accuracy for bounding boxes from RPN: 0.5275
# Loss RPN classifier: 2.2138955467865364
# Loss RPN regression: 0.09417261607013643
# Loss Detector classifier: 1.7491266095638276
# Loss Detector regression: 0.49802676022052766
# Elapsed time: 52.662728786468506[s]
# Epoch 19/100
#  82/100 [=======================>......] - ETA: 10s - rpn_cls: 2.1239 - rpn_regr: 0.0886 - detector_cls: 1.9633 - detector_regr: 0.4333Average number of overlapping bounding boxes from RPN = 21.82 for 100 previous iterations
# 100/100 [==============================] - 56s 563ms/step - rpn_cls: 2.1358 - rpn_regr: 0.0910 - detector_cls: 1.9425 - detector_regr: 0.4311
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.128712871287128
# Classifier accuracy for bounding boxes from RPN: 0.57
# Loss RPN classifier: 2.177093621165018
# Loss RPN regression: 0.10021118670701981
# Loss Detector classifier: 1.8462863810360433
# Loss Detector regression: 0.4176644602417946
# Elapsed time: 56.8399875164032[s]
# Epoch 20/100
#  60/100 [=================>............] - ETA: 22s - rpn_cls: 1.7785 - rpn_regr: 0.1210 - detector_cls: 1.7319 - detector_regr: 0.4771Exception: 'NoneType' object is not subscriptable
#  81/100 [=======================>......] - ETA: 10s - rpn_cls: 1.8616 - rpn_regr: 0.1215 - detector_cls: 1.7685 - detector_regr: 0.4737Average number of overlapping bounding boxes from RPN = 19.95 for 100 previous iterations
# 100/100 [==============================] - 54s 544ms/step - rpn_cls: 1.9404 - rpn_regr: 0.1226 - detector_cls: 1.7872 - detector_regr: 0.4708
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.198019801980198
# Classifier accuracy for bounding boxes from RPN: 0.5225
# Loss RPN classifier: 2.353623688430821
# Loss RPN regression: 0.1263772665988654
# Loss Detector classifier: 1.8647465008497237
# Loss Detector regression: 0.4516961246728897
# Elapsed time: 54.878679037094116[s]
# Epoch 21/100
#  14/100 [===>..........................] - ETA: 1:03 - rpn_cls: 2.1022 - rpn_regr: 0.0801 - detector_cls: 1.7867 - detector_regr: 0.5183Exception: 'NoneType' object is not subscriptable
#  64/100 [==================>...........] - ETA: 20s - rpn_cls: 2.0268 - rpn_regr: 0.1105 - detector_cls: 1.8418 - detector_regr: 0.4410Exception: 'NoneType' object is not subscriptable
#  80/100 [=======================>......] - ETA: 11s - rpn_cls: 1.9865 - rpn_regr: 0.1126 - detector_cls: 1.8517 - detector_regr: 0.4378Average number of overlapping bounding boxes from RPN = 21.75 for 100 previous iterations
# 100/100 [==============================] - 58s 581ms/step - rpn_cls: 1.9602 - rpn_regr: 0.1131 - detector_cls: 1.8590 - detector_regr: 0.4359
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.415841584158414
# Classifier accuracy for bounding boxes from RPN: 0.545
# Loss RPN classifier: 1.8214602715100592
# Loss RPN regression: 0.11653398032300175
# Loss Detector classifier: 1.9011472910642624
# Loss Detector regression: 0.4343447595089674
# Elapsed time: 58.65274405479431[s]
# Epoch 22/100
#  79/100 [======================>.......] - ETA: 11s - rpn_cls: 2.4493 - rpn_regr: 0.1188 - detector_cls: 1.8577 - detector_regr: 0.4244Average number of overlapping bounding boxes from RPN = 21.9 for 100 previous iterations
# 100/100 [==============================] - 57s 573ms/step - rpn_cls: 2.4271 - rpn_regr: 0.1170 - detector_cls: 1.8519 - detector_regr: 0.4285
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.346534653465348
# Classifier accuracy for bounding boxes from RPN: 0.545
# Loss RPN classifier: 2.304642221885269
# Loss RPN regression: 0.11142493911087513
# Loss Detector classifier: 1.7962806206941604
# Loss Detector regression: 0.43704362735152247
# Elapsed time: 57.8358519077301[s]
# Epoch 23/100
#  78/100 [======================>.......] - ETA: 11s - rpn_cls: 1.7486 - rpn_regr: 0.1133 - detector_cls: 1.8882 - detector_regr: 0.4560Average number of overlapping bounding boxes from RPN = 19.32 for 100 previous iterations
# 100/100 [==============================] - 56s 558ms/step - rpn_cls: 1.7546 - rpn_regr: 0.1124 - detector_cls: 1.8778 - detector_regr: 0.4561
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.376237623762375
# Classifier accuracy for bounding boxes from RPN: 0.5325
# Loss RPN classifier: 1.84147108384987
# Loss RPN regression: 0.10844981741160155
# Loss Detector classifier: 1.8334451389312745
# Loss Detector regression: 0.46356713995337484
# Elapsed time: 56.38174796104431[s]
# Epoch 24/100
#  73/100 [====================>.........] - ETA: 13s - rpn_cls: 1.4501 - rpn_regr: 0.0937 - detector_cls: 1.8384 - detector_regr: 0.4573Exception: 'NoneType' object is not subscriptable
#  77/100 [======================>.......] - ETA: 11s - rpn_cls: 1.4653 - rpn_regr: 0.0939 - detector_cls: 1.8405 - detector_regr: 0.4578Average number of overlapping bounding boxes from RPN = 21.64 for 100 previous iterations
# 100/100 [==============================] - 52s 515ms/step - rpn_cls: 1.5243 - rpn_regr: 0.0943 - detector_cls: 1.8435 - detector_regr: 0.4602
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.544554455445546
# Classifier accuracy for bounding boxes from RPN: 0.5325
# Loss RPN classifier: 1.6600527722189822
# Loss RPN regression: 0.09476175880990922
# Loss Detector classifier: 1.843810345828533
# Loss Detector regression: 0.4608566679805517
# Elapsed time: 52.023982763290405[s]
# Epoch 25/100
#  76/100 [=====================>........] - ETA: 12s - rpn_cls: 1.9392 - rpn_regr: 0.1185 - detector_cls: 1.8092 - detector_regr: 0.4176Average number of overlapping bounding boxes from RPN = 22.21 for 100 previous iterations
# 100/100 [==============================] - 54s 540ms/step - rpn_cls: 1.8314 - rpn_regr: 0.1215 - detector_cls: 1.8168 - detector_regr: 0.4169
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.465346534653467
# Classifier accuracy for bounding boxes from RPN: 0.5175
# Loss RPN classifier: 1.526373731352388
# Loss RPN regression: 0.13252992095425725
# Loss Detector classifier: 1.8559504153672606
# Loss Detector regression: 0.40363171339035037
# Elapsed time: 54.56090974807739[s]
# Epoch 26/100
#  75/100 [=====================>........] - ETA: 13s - rpn_cls: 1.0447 - rpn_regr: 0.1228 - detector_cls: 1.9524 - detector_regr: 0.4262Average number of overlapping bounding boxes from RPN = 23.79 for 100 previous iterations
# 100/100 [==============================] - 53s 526ms/step - rpn_cls: 1.0679 - rpn_regr: 0.1233 - detector_cls: 1.9366 - detector_regr: 0.4275
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.89108910891089
# Classifier accuracy for bounding boxes from RPN: 0.5325
# Loss RPN classifier: 1.1889836178217152
# Loss RPN regression: 0.12500971103087066
# Loss Detector classifier: 1.9072372314333916
# Loss Detector regression: 0.4348007010668516
# Elapsed time: 53.160480260849[s]
# Epoch 27/100
#  74/100 [=====================>........] - ETA: 13s - rpn_cls: 1.8600 - rpn_regr: 0.1133 - detector_cls: 1.8521 - detector_regr: 0.4203Average number of overlapping bounding boxes from RPN = 21.07 for 100 previous iterations
# 100/100 [==============================] - 52s 517ms/step - rpn_cls: 1.8091 - rpn_regr: 0.1173 - detector_cls: 1.8602 - detector_regr: 0.4187
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.95049504950495
# Classifier accuracy for bounding boxes from RPN: 0.525
# Loss RPN classifier: 1.8599450164140807
# Loss RPN regression: 0.13027584437746553
# Loss Detector classifier: 1.8768147879838943
# Loss Detector regression: 0.4131257086992264
# Elapsed time: 52.21291255950928[s]
# Epoch 28/100
#  73/100 [====================>.........] - ETA: 14s - rpn_cls: 0.5164 - rpn_regr: 0.1198 - detector_cls: 1.8118 - detector_regr: 0.4453Average number of overlapping bounding boxes from RPN = 21.55 for 100 previous iterations
# 100/100 [==============================] - 54s 542ms/step - rpn_cls: 0.6489 - rpn_regr: 0.1215 - detector_cls: 1.8141 - detector_regr: 0.4440
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.168316831683168
# Classifier accuracy for bounding boxes from RPN: 0.51
# Loss RPN classifier: 0.9460040939100983
# Loss RPN regression: 0.1275748058129102
# Loss Detector classifier: 1.8032087731361388
# Loss Detector regression: 0.4449723526835442
# Elapsed time: 54.7264769077301[s]
# Total loss decreased from 3.646529335797326 to 3.3217600255426913, saving weights
# Epoch 29/100
#  72/100 [====================>.........] - ETA: 16s - rpn_cls: 2.4041 - rpn_regr: 0.1258 - detector_cls: 1.7673 - detector_regr: 0.4140Average number of overlapping bounding boxes from RPN = 20.69 for 100 previous iterations
#  79/100 [======================>.......] - ETA: 12s - rpn_cls: 2.3850 - rpn_regr: 0.1262 - detector_cls: 1.7634 - detector_regr: 0.4124Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 57s 570ms/step - rpn_cls: 2.3316 - rpn_regr: 0.1272 - detector_cls: 1.7519 - detector_regr: 0.4068
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.287128712871286
# Classifier accuracy for bounding boxes from RPN: 0.5175
# Loss RPN classifier: 2.0283392954909596
# Loss RPN regression: 0.13230261689051986
# Loss Detector classifier: 1.6955406472086907
# Loss Detector regression: 0.37774308502674103
# Elapsed time: 58.27873873710632[s]
# Epoch 30/100
#  71/100 [====================>.........] - ETA: 15s - rpn_cls: 2.0176 - rpn_regr: 0.1280 - detector_cls: 1.6191 - detector_regr: 0.3637Average number of overlapping bounding boxes from RPN = 21.86 for 100 previous iterations
# 100/100 [==============================] - 54s 544ms/step - rpn_cls: 1.8997 - rpn_regr: 0.1289 - detector_cls: 1.6411 - detector_regr: 0.3707
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.07920792079208
# Classifier accuracy for bounding boxes from RPN: 0.545
# Loss RPN classifier: 1.5987342891791878
# Loss RPN regression: 0.13147793706506491
# Loss Detector classifier: 1.6580036574602126
# Loss Detector regression: 0.3872747859358788
# Elapsed time: 54.855589628219604[s]
# Epoch 31/100
#  21/100 [=====>........................] - ETA: 41s - rpn_cls: 1.5677 - rpn_regr: 0.0777 - detector_cls: 1.9441 - detector_regr: 0.4887Exception: 'NoneType' object is not subscriptable
#  66/100 [==================>...........] - ETA: 18s - rpn_cls: 1.7995 - rpn_regr: 0.0806 - detector_cls: 1.8943 - detector_regr: 0.4389Exception: 'NoneType' object is not subscriptable
#  70/100 [====================>.........] - ETA: 16s - rpn_cls: 1.7821 - rpn_regr: 0.0814 - detector_cls: 1.8907 - detector_regr: 0.4377Average number of overlapping bounding boxes from RPN = 23.63 for 100 previous iterations
# 100/100 [==============================] - 54s 545ms/step - rpn_cls: 1.6974 - rpn_regr: 0.0877 - detector_cls: 1.8629 - detector_regr: 0.4311
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.237623762376238
# Classifier accuracy for bounding boxes from RPN: 0.53
# Loss RPN classifier: 1.4638286502898559
# Loss RPN regression: 0.10610047724097967
# Loss Detector classifier: 1.7953007774055003
# Loss Detector regression: 0.41486875258386136
# Elapsed time: 54.946428537368774[s]
# Epoch 32/100
#  38/100 [==========>...................] - ETA: 35s - rpn_cls: 2.3098 - rpn_regr: 0.1310 - detector_cls: 1.9438 - detector_regr: 0.4300Exception: 'NoneType' object is not subscriptable
#  63/100 [=================>............] - ETA: 20s - rpn_cls: 2.0305 - rpn_regr: 0.1329 - detector_cls: 1.9366 - detector_regr: 0.4197Exception: 'NoneType' object is not subscriptable
#  69/100 [===================>..........] - ETA: 17s - rpn_cls: 1.9750 - rpn_regr: 0.1331 - detector_cls: 1.9306 - detector_regr: 0.4171Average number of overlapping bounding boxes from RPN = 21.88 for 100 previous iterations
# 100/100 [==============================] - 54s 545ms/step - rpn_cls: 1.8426 - rpn_regr: 0.1341 - detector_cls: 1.8933 - detector_regr: 0.4062
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.10891089108911
# Classifier accuracy for bounding boxes from RPN: 0.53
# Loss RPN classifier: 1.6010426030826068
# Loss RPN regression: 0.1375507746823132
# Loss Detector classifier: 1.788658671528101
# Loss Detector regression: 0.38093038849532607
# Elapsed time: 54.986438512802124[s]
# Epoch 33/100
#   6/100 [>.............................] - ETA: 1:07 - rpn_cls: 0.7615 - rpn_regr: 0.1017 - detector_cls: 1.7449 - detector_regr: 0.4428 Exception: 'NoneType' object is not subscriptable
#  68/100 [===================>..........] - ETA: 18s - rpn_cls: 1.5509 - rpn_regr: 0.1325 - detector_cls: 1.7623 - detector_regr: 0.3801Average number of overlapping bounding boxes from RPN = 19.93 for 100 previous iterations
# 100/100 [==============================] - 58s 585ms/step - rpn_cls: 1.7290 - rpn_regr: 0.1315 - detector_cls: 1.7628 - detector_regr: 0.3803
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.603960396039604
# Classifier accuracy for bounding boxes from RPN: 0.5275
# Loss RPN classifier: 2.0525778321824517
# Loss RPN regression: 0.122205903949216
# Loss Detector classifier: 1.7958694285154342
# Loss Detector regression: 0.3889748518168926
# Elapsed time: 58.975199699401855[s]
# Epoch 34/100
#  66/100 [==================>...........] - ETA: 18s - rpn_cls: 1.7241 - rpn_regr: 0.1436 - detector_cls: 1.8138 - detector_regr: 0.3471Exception: 'NoneType' object is not subscriptable
#  67/100 [===================>..........] - ETA: 18s - rpn_cls: 1.7246 - rpn_regr: 0.1436 - detector_cls: 1.8138 - detector_regr: 0.3472Average number of overlapping bounding boxes from RPN = 20.47 for 100 previous iterations
# 100/100 [==============================] - 54s 543ms/step - rpn_cls: 1.7461 - rpn_regr: 0.1425 - detector_cls: 1.8150 - detector_regr: 0.3533
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.88118811881188
# Classifier accuracy for bounding boxes from RPN: 0.5325
# Loss RPN classifier: 1.7703923711811143
# Loss RPN regression: 0.13041729104705155
# Loss Detector classifier: 1.816537861377001
# Loss Detector regression: 0.3753168372809887
# Elapsed time: 54.79439973831177[s]
# Epoch 35/100
#  66/100 [==================>...........] - ETA: 17s - rpn_cls: 1.9230 - rpn_regr: 0.1390 - detector_cls: 1.8809 - detector_regr: 0.4084Average number of overlapping bounding boxes from RPN = 21.19 for 100 previous iterations
# 100/100 [==============================] - 52s 518ms/step - rpn_cls: 1.8114 - rpn_regr: 0.1335 - detector_cls: 1.8301 - detector_regr: 0.3991
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.06930693069307
# Classifier accuracy for bounding boxes from RPN: 0.525
# Loss RPN classifier: 1.718496418299103
# Loss RPN regression: 0.1203160007763654
# Loss Detector classifier: 1.7125515362620354
# Loss Detector regression: 0.3777368138730526
# Elapsed time: 52.277787923812866[s]
# Epoch 36/100
#  63/100 [=================>............] - ETA: 19s - rpn_cls: 0.8753 - rpn_regr: 0.0957 - detector_cls: 1.7771 - detector_regr: 0.3511Exception: 'NoneType' object is not subscriptable
#  65/100 [==================>...........] - ETA: 18s - rpn_cls: 0.8913 - rpn_regr: 0.0957 - detector_cls: 1.7750 - detector_regr: 0.3517Average number of overlapping bounding boxes from RPN = 22.21 for 100 previous iterations
#  72/100 [====================>.........] - ETA: 14s - rpn_cls: 0.9415 - rpn_regr: 0.0957 - detector_cls: 1.7712 - detector_regr: 0.3533Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 54s 539ms/step - rpn_cls: 1.0589 - rpn_regr: 0.0980 - detector_cls: 1.7619 - detector_regr: 0.3564
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.15841584158416
# Classifier accuracy for bounding boxes from RPN: 0.555
# Loss RPN classifier: 1.3863568104987252
# Loss RPN regression: 0.10723891069181263
# Loss Detector classifier: 1.705517351925373
# Loss Detector regression: 0.3618783403933048
# Elapsed time: 54.3346893787384[s]
# Epoch 37/100
#  35/100 [=========>....................] - ETA: 34s - rpn_cls: 0.8165 - rpn_regr: 0.1071 - detector_cls: 1.5653 - detector_regr: 0.2929Exception: 'NoneType' object is not subscriptable
#  64/100 [==================>...........] - ETA: 19s - rpn_cls: 1.5034 - rpn_regr: 0.1106 - detector_cls: 1.6496 - detector_regr: 0.3374Average number of overlapping bounding boxes from RPN = 21.03 for 100 previous iterations
# 100/100 [==============================] - 55s 553ms/step - rpn_cls: 1.7881 - rpn_regr: 0.1104 - detector_cls: 1.6925 - detector_regr: 0.3539
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.514851485148515
# Classifier accuracy for bounding boxes from RPN: 0.525
# Loss RPN classifier: 2.26088867734088
# Loss RPN regression: 0.10812246278859675
# Loss Detector classifier: 1.7535341385006904
# Loss Detector regression: 0.3782544577121735
# Elapsed time: 55.88318061828613[s]
# Epoch 38/100
#  63/100 [=================>............] - ETA: 21s - rpn_cls: 0.9951 - rpn_regr: 0.1480 - detector_cls: 1.7125 - detector_regr: 0.3317Average number of overlapping bounding boxes from RPN = 19.85 for 100 previous iterations
# 100/100 [==============================] - 55s 552ms/step - rpn_cls: 1.1006 - rpn_regr: 0.1455 - detector_cls: 1.6831 - detector_regr: 0.3406
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.683168316831683
# Classifier accuracy for bounding boxes from RPN: 0.5225
# Loss RPN classifier: 1.3879031312545058
# Loss RPN regression: 0.14200465952977537
# Loss Detector classifier: 1.6230269134417177
# Loss Detector regression: 0.343659600764513
# Elapsed time: 55.80101680755615[s]
# Epoch 39/100
#  50/100 [==============>...............] - ETA: 27s - rpn_cls: 2.1145 - rpn_regr: 0.1484 - detector_cls: 1.7333 - detector_regr: 0.3718Exception: 'NoneType' object is not subscriptable
#  62/100 [=================>............] - ETA: 20s - rpn_cls: 2.0761 - rpn_regr: 0.1460 - detector_cls: 1.7274 - detector_regr: 0.3711Average number of overlapping bounding boxes from RPN = 20.05 for 100 previous iterations
# 100/100 [==============================] - 57s 568ms/step - rpn_cls: 1.9512 - rpn_regr: 0.1418 - detector_cls: 1.7413 - detector_regr: 0.3618
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.465346534653467
# Classifier accuracy for bounding boxes from RPN: 0.5125
# Loss RPN classifier: 1.5685132087263383
# Loss RPN regression: 0.13039094019681216
# Loss Detector classifier: 1.77901457965374
# Loss Detector regression: 0.3546322299540043
# Elapsed time: 57.338387966156006[s]
# Epoch 40/100
#  61/100 [=================>............] - ETA: 19s - rpn_cls: 1.4122 - rpn_regr: 0.0889 - detector_cls: 1.7066 - detector_regr: 0.3478Average number of overlapping bounding boxes from RPN = 23.45 for 100 previous iterations
# 100/100 [==============================] - 52s 515ms/step - rpn_cls: 1.2907 - rpn_regr: 0.0961 - detector_cls: 1.6899 - detector_regr: 0.3571
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.673267326732674
# Classifier accuracy for bounding boxes from RPN: 0.55
# Loss RPN classifier: 1.1466044674533589
# Loss RPN regression: 0.11037268354091793
# Loss Detector classifier: 1.682446317076683
# Loss Detector regression: 0.3626895077899098
# Elapsed time: 52.06833863258362[s]
# Total loss decreased from 3.3217600255426913 to 3.3021129758608696, saving weights
# Epoch 41/100
#  60/100 [=================>............] - ETA: 20s - rpn_cls: 1.7005 - rpn_regr: 0.1414 - detector_cls: 1.6683 - detector_regr: 0.3756Average number of overlapping bounding boxes from RPN = 24.3 for 100 previous iterations
#  97/100 [============================>.] - ETA: 1s - rpn_cls: 1.7339 - rpn_regr: 0.1328 - detector_cls: 1.6549 - detector_regr: 0.3725Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 52s 524ms/step - rpn_cls: 1.7350 - rpn_regr: 0.1324 - detector_cls: 1.6536 - detector_regr: 0.3720
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.702970297029704
# Classifier accuracy for bounding boxes from RPN: 0.5375
# Loss RPN classifier: 1.764031784474235
# Loss RPN regression: 0.11861125739756971
# Loss Detector classifier: 1.6100714126974345
# Loss Detector regression: 0.3571041277050972
# Elapsed time: 53.650216817855835[s]
# Epoch 42/100
#  59/100 [================>.............] - ETA: 21s - rpn_cls: 1.6037 - rpn_regr: 0.1521 - detector_cls: 1.6277 - detector_regr: 0.3413Average number of overlapping bounding boxes from RPN = 21.44 for 100 previous iterations
#  74/100 [=====================>........] - ETA: 13s - rpn_cls: 1.6000 - rpn_regr: 0.1478 - detector_cls: 1.6419 - detector_regr: 0.3462Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 52s 520ms/step - rpn_cls: 1.6060 - rpn_regr: 0.1439 - detector_cls: 1.6617 - detector_regr: 0.3481
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 19.306930693069308
# Classifier accuracy for bounding boxes from RPN: 0.5475
# Loss RPN classifier: 1.7306341054518517
# Loss RPN regression: 0.14015726994723082
# Loss Detector classifier: 1.7036268171668052
# Loss Detector regression: 0.34973765395581724
# Elapsed time: 52.576725482940674[s]
# Epoch 43/100
#  22/100 [=====>........................] - ETA: 39s - rpn_cls: 1.1505 - rpn_regr: 0.1668 - detector_cls: 1.7889 - detector_regr: 0.4003Exception: 'NoneType' object is not subscriptable
#  58/100 [================>.............] - ETA: 21s - rpn_cls: 1.5229 - rpn_regr: 0.1577 - detector_cls: 1.7925 - detector_regr: 0.3881Average number of overlapping bounding boxes from RPN = 20.51 for 100 previous iterations
# 100/100 [==============================] - 54s 538ms/step - rpn_cls: 1.7339 - rpn_regr: 0.1476 - detector_cls: 1.7562 - detector_regr: 0.3770
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.08910891089109
# Classifier accuracy for bounding boxes from RPN: 0.555
# Loss RPN classifier: 2.110786844004626
# Loss RPN regression: 0.12651211380027236
# Loss Detector classifier: 1.6854756730794906
# Loss Detector regression: 0.3620499784499407
# Elapsed time: 54.30175590515137[s]
# Epoch 44/100
#  10/100 [==>...........................] - ETA: 45s - rpn_cls: 2.3806 - rpn_regr: 0.0896 - detector_cls: 1.7121 - detector_regr: 0.3012Exception: 'NoneType' object is not subscriptable
#  28/100 [=======>......................] - ETA: 43s - rpn_cls: 1.7152 - rpn_regr: 0.1029 - detector_cls: 1.7615 - detector_regr: 0.3342Exception: 'NoneType' object is not subscriptable
#  57/100 [================>.............] - ETA: 24s - rpn_cls: 1.4260 - rpn_regr: 0.1175 - detector_cls: 1.7023 - detector_regr: 0.3496Average number of overlapping bounding boxes from RPN = 20.35 for 100 previous iterations
# Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 58s 584ms/step - rpn_cls: 1.3222 - rpn_regr: 0.1266 - detector_cls: 1.6549 - detector_regr: 0.3481
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.712871287128714
# Classifier accuracy for bounding boxes from RPN: 0.5425
# Loss RPN classifier: 1.2791623538483663
# Loss RPN regression: 0.13545883496291936
# Loss Detector classifier: 1.6180469618737698
# Loss Detector regression: 0.35908632673323154
# Elapsed time: 58.951225996017456[s]
# Epoch 45/100
#  47/100 [=============>................] - ETA: 27s - rpn_cls: 0.8330 - rpn_regr: 0.1228 - detector_cls: 1.6609 - detector_regr: 0.3291Exception: 'NoneType' object is not subscriptable
#  56/100 [===============>..............] - ETA: 22s - rpn_cls: 0.8634 - rpn_regr: 0.1224 - detector_cls: 1.6472 - detector_regr: 0.3285Average number of overlapping bounding boxes from RPN = 23.45 for 100 previous iterations
# 100/100 [==============================] - 52s 518ms/step - rpn_cls: 0.9782 - rpn_regr: 0.1253 - detector_cls: 1.5814 - detector_regr: 0.3248
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.475247524752476
# Classifier accuracy for bounding boxes from RPN: 0.58
# Loss RPN classifier: 1.0519348053674709
# Loss RPN regression: 0.125827247928828
# Loss Detector classifier: 1.508752147257328
# Loss Detector regression: 0.3304843593388796
# Elapsed time: 52.45865845680237[s]
# Total loss decreased from 3.3021129758608696 to 3.0169985598925066, saving weights
# Epoch 46/100
#  55/100 [===============>..............] - ETA: 23s - rpn_cls: 2.2445 - rpn_regr: 0.1286 - detector_cls: 1.4854 - detector_regr: 0.2825Average number of overlapping bounding boxes from RPN = 22.56 for 100 previous iterations
# 100/100 [==============================] - 52s 517ms/step - rpn_cls: 2.0018 - rpn_regr: 0.1227 - detector_cls: 1.5423 - detector_regr: 0.3097
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.237623762376238
# Classifier accuracy for bounding boxes from RPN: 0.5575
# Loss RPN classifier: 1.4646596615269012
# Loss RPN regression: 0.1124646758241579
# Loss Detector classifier: 1.685951939225197
# Loss Detector regression: 0.3461718677356839
# Elapsed time: 53.02968430519104[s]
# Epoch 47/100
#  54/100 [===============>..............] - ETA: 24s - rpn_cls: 1.4305 - rpn_regr: 0.0909 - detector_cls: 1.5841 - detector_regr: 0.3735Average number of overlapping bounding boxes from RPN = 24.36 for 100 previous iterations
#  83/100 [=======================>......] - ETA: 8s - rpn_cls: 1.3867 - rpn_regr: 0.0954 - detector_cls: 1.6164 - detector_regr: 0.3642Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 57s 569ms/step - rpn_cls: 1.3640 - rpn_regr: 0.0971 - detector_cls: 1.6227 - detector_regr: 0.3616
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 24.00990099009901
# Classifier accuracy for bounding boxes from RPN: 0.5225
# Loss RPN classifier: 1.2736027773471092
# Loss RPN regression: 0.10350457346066833
# Loss Detector classifier: 1.6476990643143654
# Loss Detector regression: 0.3488739852979779
# Elapsed time: 57.507208824157715[s]
# Epoch 48/100
#  53/100 [==============>...............] - ETA: 25s - rpn_cls: 1.3500 - rpn_regr: 0.1085 - detector_cls: 1.6330 - detector_regr: 0.3285Average number of overlapping bounding boxes from RPN = 23.34 for 100 previous iterations
#  66/100 [==================>...........] - ETA: 18s - rpn_cls: 1.3899 - rpn_regr: 0.1093 - detector_cls: 1.6299 - detector_regr: 0.3320Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 54s 539ms/step - rpn_cls: 1.3935 - rpn_regr: 0.1084 - detector_cls: 1.6394 - detector_regr: 0.3354
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.138613861386137
# Classifier accuracy for bounding boxes from RPN: 0.525
# Loss RPN classifier: 1.408886517960374
# Loss RPN regression: 0.10854354887735099
# Loss Detector classifier: 1.6766522806882858
# Loss Detector regression: 0.33956118252128364
# Elapsed time: 54.46634078025818[s]
# Epoch 49/100
#  52/100 [==============>...............] - ETA: 27s - rpn_cls: 1.0883 - rpn_regr: 0.1162 - detector_cls: 1.5954 - detector_regr: 0.3175Average number of overlapping bounding boxes from RPN = 23.17 for 100 previous iterations
# 100/100 [==============================] - 54s 538ms/step - rpn_cls: 1.2587 - rpn_regr: 0.1137 - detector_cls: 1.5685 - detector_regr: 0.3232
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.831683168316832
# Classifier accuracy for bounding boxes from RPN: 0.5275
# Loss RPN classifier: 1.5931306824236515
# Loss RPN regression: 0.11342580049298703
# Loss Detector classifier: 1.5953115445375443
# Loss Detector regression: 0.33685911478474734
# Elapsed time: 54.29084300994873[s]
# Epoch 50/100
#  51/100 [==============>...............] - ETA: 25s - rpn_cls: 2.3412 - rpn_regr: 0.1181 - detector_cls: 1.6184 - detector_regr: 0.3884Average number of overlapping bounding boxes from RPN = 20.64 for 100 previous iterations
# 100/100 [==============================] - 53s 527ms/step - rpn_cls: 2.0589 - rpn_regr: 0.1214 - detector_cls: 1.5997 - detector_regr: 0.3726
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.11881188118812
# Classifier accuracy for bounding boxes from RPN: 0.5375
# Loss RPN classifier: 1.8326330166382387
# Loss RPN regression: 0.11801046914421022
# Loss Detector classifier: 1.589825132638216
# Loss Detector regression: 0.3507591442018747
# Elapsed time: 53.194668769836426[s]
# Epoch 51/100
#  50/100 [==============>...............] - ETA: 25s - rpn_cls: 0.8303 - rpn_regr: 0.1180 - detector_cls: 1.5253 - detector_regr: 0.3640Average number of overlapping bounding boxes from RPN = 23.3 for 100 previous iterations
# 100/100 [==============================] - 51s 514ms/step - rpn_cls: 1.1599 - rpn_regr: 0.1237 - detector_cls: 1.5102 - detector_regr: 0.3636
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.91089108910891
# Classifier accuracy for bounding boxes from RPN: 0.59
# Loss RPN classifier: 1.5310319058433157
# Loss RPN regression: 0.126672922661528
# Loss Detector classifier: 1.4958386054635049
# Loss Detector regression: 0.3537143211066723
# Elapsed time: 51.93020582199097[s]
# Epoch 52/100
#  49/100 [=============>................] - ETA: 29s - rpn_cls: 1.7796 - rpn_regr: 0.1325 - detector_cls: 1.7510 - detector_regr: 0.3926Average number of overlapping bounding boxes from RPN = 22.03 for 100 previous iterations
#  80/100 [=======================>......] - ETA: 11s - rpn_cls: 1.7679 - rpn_regr: 0.1318 - detector_cls: 1.7267 - detector_regr: 0.3801Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 57s 573ms/step - rpn_cls: 1.7267 - rpn_regr: 0.1325 - detector_cls: 1.7122 - detector_regr: 0.3751
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.10891089108911
# Classifier accuracy for bounding boxes from RPN: 0.5275
# Loss RPN classifier: 1.5328326229814082
# Loss RPN regression: 0.13298313675448298
# Loss Detector classifier: 1.644639614969492
# Loss Detector regression: 0.3576806752383709
# Elapsed time: 57.83270072937012[s]
# Epoch 53/100
#  36/100 [=========>....................] - ETA: 31s - rpn_cls: 1.1585 - rpn_regr: 0.1146 - detector_cls: 1.6664 - detector_regr: 0.3805Exception: 'NoneType' object is not subscriptable
#  48/100 [=============>................] - ETA: 26s - rpn_cls: 1.3287 - rpn_regr: 0.1126 - detector_cls: 1.6805 - detector_regr: 0.3871Average number of overlapping bounding boxes from RPN = 23.84 for 100 previous iterations
#  96/100 [===========================>..] - ETA: 2s - rpn_cls: 1.7088 - rpn_regr: 0.1093 - detector_cls: 1.6733 - detector_regr: 0.3888Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 53s 526ms/step - rpn_cls: 1.7187 - rpn_regr: 0.1092 - detector_cls: 1.6718 - detector_regr: 0.3883
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.435643564356436
# Classifier accuracy for bounding boxes from RPN: 0.545
# Loss RPN classifier: 1.960600189302789
# Loss RPN regression: 0.10754160771146416
# Loss Detector classifier: 1.6234213131666184
# Loss Detector regression: 0.3744160739332438
# Elapsed time: 53.08605337142944[s]
# Epoch 54/100
#  20/100 [=====>........................] - ETA: 41s - rpn_cls: 1.9490 - rpn_regr: 0.1128 - detector_cls: 1.4128 - detector_regr: 0.3155Exception: 'NoneType' object is not subscriptable
# ...
#  36/100 [=========>....................] - ETA: 32s - rpn_cls: 1.8547 - rpn_regr: 0.1074 - detector_cls: 1.3602 - detector_regr: 0.3923Exception: 'NoneType' object is not subscriptable
#  92/100 [==========================>...] - ETA: 4s - rpn_cls: 1.5478 - rpn_regr: 0.1171 - detector_cls: 1.3223 - detector_regr: 0.3604Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 52s 521ms/step - rpn_cls: 1.5518 - rpn_regr: 0.1172 - detector_cls: 1.3222 - detector_regr: 0.3584
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.97029702970297
# Classifier accuracy for bounding boxes from RPN: 0.575
# Loss RPN classifier: 1.638865161502477
# Loss RPN regression: 0.1190785995312035
# Loss Detector classifier: 1.310647594332695
# Loss Detector regression: 0.3322677217796445
# Elapsed time: 52.57447934150696[s]
# Epoch 84/100
#   7/100 [=>............................] - ETA: 45s - rpn_cls: 1.0053 - rpn_regr: 0.0907 - detector_cls: 1.1532 - detector_regr: 0.1717Exception: 'NoneType' object is not subscriptable
#   9/100 [=>............................] - ETA: 49s - rpn_cls: 0.9875 - rpn_regr: 0.1002 - detector_cls: 1.1812 - detector_regr: 0.1874Exception: 'NoneType' object is not subscriptable
#  17/100 [====>.........................] - ETA: 45s - rpn_cls: 1.0140 - rpn_regr: 0.1079 - detector_cls: 1.2705 - detector_regr: 0.2135Average number of overlapping bounding boxes from RPN = 23.03 for 100 previous iterations
# 100/100 [==============================] - 51s 511ms/step - rpn_cls: 1.3249 - rpn_regr: 0.1120 - detector_cls: 1.4156 - detector_regr: 0.2756
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.693069306930692
# Classifier accuracy for bounding boxes from RPN: 0.615
# Loss RPN classifier: 1.6459915655273127
# Loss RPN regression: 0.10859787326306104
# Loss Detector classifier: 1.2906712821125985
# Loss Detector regression: 0.2867896944656968
# Elapsed time: 51.72455382347107[s]
# Epoch 85/100
#  16/100 [===>..........................] - ETA: 44s - rpn_cls: 0.8625 - rpn_regr: 0.1483 - detector_cls: 0.9649 - detector_regr: 0.3074Average number of overlapping bounding boxes from RPN = 21.88 for 100 previous iterations
#  95/100 [===========================>..] - ETA: 2s - rpn_cls: 1.2183 - rpn_regr: 0.1312 - detector_cls: 1.1433 - detector_regr: 0.3059Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 52s 525ms/step - rpn_cls: 1.2228 - rpn_regr: 0.1304 - detector_cls: 1.1466 - detector_regr: 0.3052
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.465346534653467
# Classifier accuracy for bounding boxes from RPN: 0.6275
# Loss RPN classifier: 1.2928392644722684
# Loss RPN regression: 0.11519805804826319
# Loss Detector classifier: 1.2158342356979848
# Loss Detector regression: 0.28809082770720124
# Elapsed time: 52.95563578605652[s]
# Epoch 86/100
#  15/100 [===>..........................] - ETA: 44s - rpn_cls: 0.3397 - rpn_regr: 0.1644 - detector_cls: 1.4822 - detector_regr: 0.3995Average number of overlapping bounding boxes from RPN = 22.87 for 100 previous iterations
#  90/100 [==========================>...] - ETA: 5s - rpn_cls: 0.9291 - rpn_regr: 0.1296 - detector_cls: 1.3979 - detector_regr: 0.3208Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 53s 526ms/step - rpn_cls: 0.9628 - rpn_regr: 0.1279 - detector_cls: 1.3866 - detector_regr: 0.3176
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.08910891089109
# Classifier accuracy for bounding boxes from RPN: 0.63
# Loss RPN classifier: 1.3652875437223242
# Loss RPN regression: 0.11192215911112725
# Loss Detector classifier: 1.285135278850794
# Loss Detector regression: 0.2929067659378052
# Elapsed time: 53.06790781021118[s]
# Epoch 87/100
#  14/100 [===>..........................] - ETA: 44s - rpn_cls: 3.5666 - rpn_regr: 0.1134 - detector_cls: 1.6714 - detector_regr: 0.2895Average number of overlapping bounding boxes from RPN = 22.13 for 100 previous iterations
#  59/100 [================>.............] - ETA: 21s - rpn_cls: 2.2255 - rpn_regr: 0.1106 - detector_cls: 1.3713 - detector_regr: 0.2886Exception: 'NoneType' object is not subscriptable
#  65/100 [==================>...........] - ETA: 18s - rpn_cls: 2.1594 - rpn_regr: 0.1099 - detector_cls: 1.3678 - detector_regr: 0.2911Exception: 'NoneType' object is not subscriptable
#  92/100 [==========================>...] - ETA: 4s - rpn_cls: 1.9687 - rpn_regr: 0.1090 - detector_cls: 1.3550 - detector_regr: 0.3019Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 52s 518ms/step - rpn_cls: 1.9440 - rpn_regr: 0.1093 - detector_cls: 1.3518 - detector_regr: 0.3044
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.435643564356436
# Classifier accuracy for bounding boxes from RPN: 0.595
# Loss RPN classifier: 1.7409766440852752
# Loss RPN regression: 0.11680435003247112
# Loss Detector classifier: 1.316219698935747
# Loss Detector regression: 0.3286522005870938
# Elapsed time: 52.29888343811035[s]
# Epoch 88/100
#  13/100 [==>...........................] - ETA: 44s - rpn_cls: 1.4594 - rpn_regr: 0.1501 - detector_cls: 1.0262 - detector_regr: 0.3290Average number of overlapping bounding boxes from RPN = 21.21 for 100 previous iterations
# 100/100 [==============================] - 51s 510ms/step - rpn_cls: 1.3872 - rpn_regr: 0.1132 - detector_cls: 1.2623 - detector_regr: 0.3408
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.673267326732674
# Classifier accuracy for bounding boxes from RPN: 0.62
# Loss RPN classifier: 1.5878146982622257
# Loss RPN regression: 0.10939328853972256
# Loss Detector classifier: 1.3826381087303161
# Loss Detector regression: 0.3495555591210723
# Elapsed time: 51.556474685668945[s]
# Epoch 89/100
#  12/100 [==>...........................] - ETA: 44s - rpn_cls: 0.8880 - rpn_regr: 0.0628 - detector_cls: 1.1218 - detector_regr: 0.2319Average number of overlapping bounding boxes from RPN = 23.24 for 100 previous iterations
# 100/100 [==============================] - 51s 508ms/step - rpn_cls: 1.0532 - rpn_regr: 0.0858 - detector_cls: 1.2196 - detector_regr: 0.2685
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 24.168316831683168
# Classifier accuracy for bounding boxes from RPN: 0.6075
# Loss RPN classifier: 1.2390287042685573
# Loss RPN regression: 0.10113077053800225
# Loss Detector classifier: 1.2868904156982899
# Loss Detector regression: 0.29760537426918743
# Elapsed time: 51.356815576553345[s]
# Epoch 90/100
#  11/100 [==>...........................] - ETA: 46s - rpn_cls: 0.6930 - rpn_regr: 0.1072 - detector_cls: 1.3327 - detector_regr: 0.2581Average number of overlapping bounding boxes from RPN = 24.5 for 100 previous iterations
# 100/100 [==============================] - 52s 520ms/step - rpn_cls: 0.9472 - rpn_regr: 0.1254 - detector_cls: 1.2675 - detector_regr: 0.3096
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 20.762376237623762
# Classifier accuracy for bounding boxes from RPN: 0.6275
# Loss RPN classifier: 0.8961188613306337
# Loss RPN regression: 0.12986533063463868
# Loss Detector classifier: 1.1766926114261151
# Loss Detector regression: 0.3000522584840655
# Elapsed time: 52.54495406150818[s]
# Total loss decreased from 2.782302905869759 to 2.502729061875453, saving weights
# Epoch 91/100
#  10/100 [==>...........................] - ETA: 47s - rpn_cls: 0.3189 - rpn_regr: 0.0925 - detector_cls: 1.1503 - detector_regr: 0.4125Average number of overlapping bounding boxes from RPN = 19.95 for 100 previous iterations
# 100/100 [==============================] - 51s 514ms/step - rpn_cls: 0.9843 - rpn_regr: 0.1018 - detector_cls: 1.2250 - detector_regr: 0.3656
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 23.059405940594058
# Classifier accuracy for bounding boxes from RPN: 0.58
# Loss RPN classifier: 1.4159013177452096
# Loss RPN regression: 0.09527579929679632
# Loss Detector classifier: 1.2907877150177955
# Loss Detector regression: 0.3454251877218485
# Elapsed time: 52.654069900512695[s]
# Epoch 92/100
#   9/100 [=>............................] - ETA: 46s - rpn_cls: 0.5017 - rpn_regr: 0.1264 - detector_cls: 1.2005 - detector_regr: 0.4928  Average number of overlapping bounding boxes from RPN = 23.17 for 100 previous iterations
# 100/100 [==============================] - 51s 513ms/step - rpn_cls: 1.5384 - rpn_regr: 0.1259 - detector_cls: 1.2666 - detector_regr: 0.3879
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.95049504950495
# Classifier accuracy for bounding boxes from RPN: 0.61
# Loss RPN classifier: 1.5478254741260449
# Loss RPN regression: 0.11391369157470763
# Loss Detector classifier: 1.2806095042824746
# Loss Detector regression: 0.35040221489965917
# Elapsed time: 51.84958600997925[s]
# Epoch 93/100
#   8/100 [=>............................] - ETA: 46s - rpn_cls: 1.5620 - rpn_regr: 0.1799 - detector_cls: 1.6137 - detector_regr: 0.5216Average number of overlapping bounding boxes from RPN = 22.97 for 100 previous iterations
#  79/100 [======================>.......] - ETA: 10s - rpn_cls: 1.3259 - rpn_regr: 0.1276 - detector_cls: 1.2611 - detector_regr: 0.3657Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 52s 516ms/step - rpn_cls: 1.2718 - rpn_regr: 0.1249 - detector_cls: 1.2431 - detector_regr: 0.3587
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 24.198019801980198
# Classifier accuracy for bounding boxes from RPN: 0.6425
# Loss RPN classifier: 1.0905549102549648
# Loss RPN regression: 0.10991197858937085
# Loss Detector classifier: 1.1667030991613865
# Loss Detector regression: 0.32914075382053853
# Elapsed time: 52.115450620651245[s]
# Epoch 94/100
#   7/100 [=>............................] - ETA: 45s - rpn_cls: 4.4076 - rpn_regr: 0.0951 - detector_cls: 1.3730 - detector_regr: 0.2505Average number of overlapping bounding boxes from RPN = 23.69 for 100 previous iterations
#  41/100 [===========>..................] - ETA: 29s - rpn_cls: 2.5254 - rpn_regr: 0.1090 - detector_cls: 1.3136 - detector_regr: 0.3350Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 51s 514ms/step - rpn_cls: 1.9679 - rpn_regr: 0.1111 - detector_cls: 1.3392 - detector_regr: 0.3378
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.514851485148515
# Classifier accuracy for bounding boxes from RPN: 0.6075
# Loss RPN classifier: 1.3124684487547977
# Loss RPN regression: 0.12164213893935084
# Loss Detector classifier: 1.3392207787930965
# Loss Detector regression: 0.3168619281053543
# Elapsed time: 51.889848709106445[s]
# Epoch 95/100
#   6/100 [>.............................] - ETA: 47s - rpn_cls: 1.6350e-04 - rpn_regr: 0.2193 - detector_cls: 1.2011 - detector_regr: 0.3688Average number of overlapping bounding boxes from RPN = 22.33 for 100 previous iterations
#  57/100 [================>.............] - ETA: 21s - rpn_cls: 0.8115 - rpn_regr: 0.1496 - detector_cls: 1.3106 - detector_regr: 0.3591Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 51s 514ms/step - rpn_cls: 1.0347 - rpn_regr: 0.1391 - detector_cls: 1.3005 - detector_regr: 0.3529
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.0
# Classifier accuracy for bounding boxes from RPN: 0.625
# Loss RPN classifier: 1.3574272983948443
# Loss RPN regression: 0.12824094956740736
# Loss Detector classifier: 1.3232973131537438
# Loss Detector regression: 0.333602674305439
# Elapsed time: 51.936487436294556[s]
# Epoch 96/100
#   5/100 [>.............................] - ETA: 47s - rpn_cls: 0.9894 - rpn_regr: 0.0972 - detector_cls: 1.0066 - detector_regr: 0.2634  Average number of overlapping bounding boxes from RPN = 21.47 for 100 previous iterations
#  33/100 [========>.....................] - ETA: 34s - rpn_cls: 1.0079 - rpn_regr: 0.1035 - detector_cls: 1.1262 - detector_regr: 0.3002Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 52s 521ms/step - rpn_cls: 1.1314 - rpn_regr: 0.0974 - detector_cls: 1.1980 - detector_regr: 0.3352
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 24.10891089108911
# Classifier accuracy for bounding boxes from RPN: 0.6
# Loss RPN classifier: 1.2350492926940049
# Loss RPN regression: 0.10341700281016529
# Loss Detector classifier: 1.2032535061985254
# Loss Detector regression: 0.34318580709397795
# Elapsed time: 52.55543828010559[s]
# Epoch 97/100
#   4/100 [>.............................] - ETA: 49s - rpn_cls: 0.9882 - rpn_regr: 0.1237 - detector_cls: 0.7037 - detector_regr: 0.3643  Average number of overlapping bounding boxes from RPN = 24.31 for 100 previous iterations
# 100/100 [==============================] - 51s 508ms/step - rpn_cls: 1.8558 - rpn_regr: 0.1224 - detector_cls: 1.2592 - detector_regr: 0.3120
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.18811881188119
# Classifier accuracy for bounding boxes from RPN: 0.6425
# Loss RPN classifier: 1.7220213921189969
# Loss RPN regression: 0.11581034939736128
# Loss Detector classifier: 1.2443796095252038
# Loss Detector regression: 0.32441026436164977
# Elapsed time: 51.266140937805176[s]
# Epoch 98/100
#   3/100 [..............................] - ETA: 50s - rpn_cls: 0.9265 - rpn_regr: 0.1438 - detector_cls: 1.1602 - detector_regr: 0.3112Average number of overlapping bounding boxes from RPN = 21.17 for 100 previous iterations
# 100/100 [==============================] - 52s 515ms/step - rpn_cls: 0.8761 - rpn_regr: 0.1168 - detector_cls: 1.2937 - detector_regr: 0.3412
# Exception: 'NoneType' object is not subscriptable
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 21.08910891089109
# Classifier accuracy for bounding boxes from RPN: 0.6075
# Loss RPN classifier: 1.3134790397911007
# Loss RPN regression: 0.11560374549590051
# Loss Detector classifier: 1.2880702524632215
# Loss Detector regression: 0.32657081574201585
# Elapsed time: 52.31770086288452[s]
# Epoch 99/100
#   2/100 [..............................] - ETA: 48s - rpn_cls: 4.6941 - rpn_regr: 0.1557 - detector_cls: 1.1160 - detector_regr: 0.4579Average number of overlapping bounding boxes from RPN = 21.14 for 100 previous iterations
#  94/100 [===========================>..] - ETA: 3s - rpn_cls: 1.4768 - rpn_regr: 0.1088 - detector_cls: 1.2025 - detector_regr: 0.3102Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 52s 516ms/step - rpn_cls: 1.4748 - rpn_regr: 0.1093 - detector_cls: 1.2009 - detector_regr: 0.3104
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 24.019801980198018
# Classifier accuracy for bounding boxes from RPN: 0.6275
# Loss RPN classifier: 1.417437853180644
# Loss RPN regression: 0.11469563480466605
# Loss Detector classifier: 1.173319953456521
# Loss Detector regression: 0.31419658672064543
# Elapsed time: 52.136276721954346[s]
# Epoch 100/100
#   1/100 [..............................] - ETA: 51s - rpn_cls: 1.2837 - rpn_regr: 0.0581 - detector_cls: 0.6891 - detector_regr: 0.3904Average number of overlapping bounding boxes from RPN = 24.0 for 100 previous iterations
#  24/100 [======>.......................] - ETA: 39s - rpn_cls: 1.3958 - rpn_regr: 0.1470 - detector_cls: 1.5126 - detector_regr: 0.3343Exception: 'NoneType' object is not subscriptable
# 100/100 [==============================] - 51s 511ms/step - rpn_cls: 1.4794 - rpn_regr: 0.1312 - detector_cls: 1.4004 - detector_regr: 0.3087
# Mean number of bounding boxes from RPN overlapping ground truth boxes: 22.376237623762375
# Classifier accuracy for bounding boxes from RPN: 0.65
# Loss RPN classifier: 1.3923324271005908
# Loss RPN regression: 0.12259354662150145
# Loss Detector classifier: 1.213458932340145
# Loss Detector regression: 0.2947437760978937
# Elapsed time: 51.642256021499634[s]
# training is done
# -------------------------------
# path to config file : ./save/train_20190611-024351_config.pickle
# -------------------------------

# %%
#推定
# %run predict.py -i ./simpsons_testset -c ./save/train_20190611-024351_config.pickle
# Out:
# abraham_grampa_simpson_21.jpg
# [('bart_simpson', 96.01855278015137), ('lisa_simpson', 67.62637495994568)]
# Elapsed time = 7.205219268798828[s]
# apu_nahasapeemapetilon_11.jpg
# []
# Elapsed time = 1.1826567649841309[s]
# bart_simpson_0.jpg
# [('bart_simpson', 87.58527636528015)]
# Elapsed time = 1.148132562637329[s]
# charles_montgomery_burns_20.jpg
# [('principal_skinner', 68.21582913398743), ('bart_simpson', 65.5188262462616)]
# Elapsed time = 1.1689538955688477[s]
# charles_montgomery_burns_31.jpg
# [('ned_flanders', 90.76451659202576), ('bart_simpson', 80.86066842079163)]
# Elapsed time = 1.2389309406280518[s]
# chief_wiggum_12.jpg
# [('principal_skinner', 80.77336549758911)]
# Elapsed time = 1.2695658206939697[s]
# chief_wiggum_9.jpg
# []
# Elapsed time = 1.1901452541351318[s]
# comic_book_guy_46.jpg
# [('bart_simpson', 80.95431923866272)]
# Elapsed time = 1.1839168071746826[s]
# kent_brockman_18.jpg
# [('principal_skinner', 63.03527355194092)]
# Elapsed time = 1.1895599365234375[s]
# kent_brockman_39.jpg
# []
# Elapsed time = 1.1927626132965088[s]
# lisa_simpson_18.jpg
# [('bart_simpson', 81.48791790008545)]
# Elapsed time = 1.1787142753601074[s]
# lisa_simpson_39.jpg
# [('bart_simpson', 64.94417190551758)]
# Elapsed time = 1.145097255706787[s]
# marge_simpson_22.jpg
# [('marge_simpson', 80.446457862854)]
# Elapsed time = 1.1901674270629883[s]
# marge_simpson_26.jpg
# [('marge_simpson', 93.397057056427), ('bart_simpson', 80.35295009613037)]
# Elapsed time = 1.1938226222991943[s]
# marge_simpson_32.jpg
# [('marge_simpson', 77.99555659294128), ('bart_simpson', 63.0823016166687)]
# Elapsed time = 1.2001926898956299[s]
# milhouse_van_houten_15.jpg
# [('bart_simpson', 96.48623466491699), ('milhouse_van_houten', 62.45952844619751)]
# Elapsed time = 1.2154338359832764[s]
# milhouse_van_houten_3.jpg
# [('bart_simpson', 86.24644875526428)]
# Elapsed time = 1.1800625324249268[s]
# moe_szyslak_43.jpg
# [('bart_simpson', 58.16708207130432)]
# Elapsed time = 1.1906652450561523[s]
# moe_szyslak_5.jpg
# [('bart_simpson', 86.07344627380371), ('lisa_simpson', 68.37464570999146)]
# Elapsed time = 1.1951963901519775[s]
# nelson_muntz_6.jpg
# [('principal_skinner', 57.52577185630798)]
# Elapsed time = 1.1824815273284912[s]
# principal_skinner_22.jpg
# [('principal_skinner', 87.0769739151001)]
# Elapsed time = 1.1514904499053955[s]
# principal_skinner_25.jpg
# [('principal_skinner', 78.06598544120789), ('bart_simpson', 55.17047047615051)]
# Elapsed time = 1.1987452507019043[s]
# principal_skinner_40.jpg
# [('principal_skinner', 84.459787607193)]
# Elapsed time = 1.1560947895050049[s]
# principal_skinner_8.jpg
# [('principal_skinner', 91.40356779098511)]
# Elapsed time = 1.1894292831420898[s]
# sideshow_bob_1.jpg
# []
# Elapsed time = 1.165701150894165[s]

# %% [markdown]
# 学習に時間がかかるため、エポック数、バッチ数を100として学習、推定を行なった。学習が不足しているせいか、一部で推定できていない画像があった。

# %% [markdown]
# ## 【問題2】論文と実装の対応
#
# コードリーディングを行ってください。
#
# まず、Faster R-CNN\[1\]において重要だと考えた部分を列挙してください。そして、それに対応するコードを見つけてください。
#
# （例）
#
# - RPNを実現しているコードはどこか
# - RoIプーリングを実現しているコードはどこか
#
# フレームワークには畳み込み層など一般的なものはクラスが用意されていますが、RoIプーリングなど特定の手法限定のものは用意されていません。オリジナルのレイヤーを作成することが可能であり、Kerasであれば以下のページに情報がまとまっています。
#
# [オリジナルのKerasレイヤーを作成する - Keras Documentation](https://keras.io/ja/layers/writing-your-own-keras-layers/)
#
# 参考
#
# KerasではVGG16のクラスが用意されているため、簡単に利用ができます。include_top=Falseの引数を与えることで、出力のための全結合層部分が除かれます。weights='imagenet'でImageNetを利用した学習済みモデルも手に入り、転移学習が行えます。weights='None'とすればランダムな初期化となります。
#
# [Applications - Keras Documentation](https://keras.io/ja/applications/#vgg16)
#
# - RPNを実現しているコードはどこか
# - RoIプーリングを実現しているコードはどこか

# %% [markdown]
# ### ・RPNを実現しているコードはどこか
#
# **faster_rcnn.py**

# %%
#nn : resnet.py
num_anchors = len(C.anchor_box_scales) * len(C.anchor_box_ratios)
rpn = nn.rpn(shared_layers, num_anchors)

# %% [markdown]
# **resnet.py**

# %%
def rpn(base_layers,num_anchors):

    x = Convolution2D(512, (3, 3), padding='same', activation='relu', kernel_initializer='normal', name='rpn_conv1')(base_layers)

    x_class = Convolution2D(num_anchors, (1, 1), activation='sigmoid', kernel_initializer='uniform', name='rpn_out_class')(x)
    x_regr = Convolution2D(num_anchors * 4, (1, 1), activation='linear', kernel_initializer='zero', name='rpn_out_regress')(x)

    return [x_class, x_regr, base_layers]

# %% [markdown]
# ### ・RoIプーリングを実現しているコードはどこか
#
# **faster_rcnn.py**

# %%
#nn : resnet.py
classifier = nn.classifier(shared_layers, roi_input, C.num_rois, 
                           nb_classes=len(classes_count), trainable=True)

# %% [markdown]
# **resnet.py**

# %%
def classifier(base_layers, input_rois, num_rois, nb_classes = 21, trainable=False):

    pooling_regions = 14
    input_shape = (num_rois,14,14,1024)
    out_roi_pool = RoiPoolingConv(pooling_regions, num_rois)([base_layers, input_rois])
    out = classifier_layers(out_roi_pool, input_shape=input_shape, trainable=True)

    out = TimeDistributed(Flatten())(out)

    out_class = TimeDistributed(Dense(nb_classes, activation='softmax', kernel_initializer='zero'), name='dense_class_{}'.format(nb_classes))(out)
    # note: no regression target for bg class
    out_regr = TimeDistributed(Dense(4 * (nb_classes-1), activation='linear', kernel_initializer='zero'),
    name='dense_regress_{}'.format(nb_classes))(out)
    return [out_class, out_regr]

# %% [markdown]
# **RoiPoolingConv.py**

# %%
class RoiPoolingConv(Layer):
    '''
    2次元入力用のプーリング層
    See Spatial Pyramid Pooling in Deep Convolutional Networks for Visual Recognition,
    K. He, X. Zhang, S. Ren, J. Sun
    
    # Arguments
        pool_size: int
            プーリング領域のサイズ. pool_size = 7 will result in a 7x7 region.
        num_rois: 関心領域の数
   
   # Input shape
        list of two 4D tensors [X_img,X_roi] with shape:
        X_img:
        `(1, channels, rows, cols)` if dim_ordering='th'
        or 4D tensor with shape:
        `(1, rows, cols, channels)` if dim_ordering='tf'.
        X_roi:
        `(1,num_rois,4)` list of rois, with ordering (x,y,w,h)
   
   # Output shape
        3D tensor with shape:
        `(1, num_rois, channels, pool_size, pool_size)`
    '''
    def __init__(self, pool_size, num_rois, **kwargs):

        self.dim_ordering = K.image_dim_ordering()
        assert self.dim_ordering in {'tf', 'th'}, 'dim_ordering must be in {tf, th}'

        self.pool_size = pool_size
        self.num_rois = num_rois

        super(RoiPoolingConv, self).__init__(**kwargs)

    def build(self, input_shape):
        if self.dim_ordering == 'th':
            self.nb_channels = input_shape[0][1]
        elif self.dim_ordering == 'tf':
            self.nb_channels = input_shape[0][3]

    def compute_output_shape(self, input_shape):
        if self.dim_ordering == 'th':
            return None, self.num_rois, self.nb_channels, self.pool_size, self.pool_size
        else:
            return None, self.num_rois, self.pool_size, self.pool_size, self.nb_channels

    def call(self, x, mask=None):

        assert(len(x) == 2)

        img = x[0]
        rois = x[1]

        input_shape = K.shape(img)

        outputs = []

        for roi_idx in range(self.num_rois):

            x = rois[0, roi_idx, 0]
            y = rois[0, roi_idx, 1]
            w = rois[0, roi_idx, 2]
            h = rois[0, roi_idx, 3]
            
            row_length = w / float(self.pool_size)
            col_length = h / float(self.pool_size)

            num_pool_regions = self.pool_size

            #NOTE: the RoiPooling implementation differs between theano and tensorflow due to the lack of a resize op
            # in theano. The theano implementation is much less efficient and leads to long compile times

            if self.dim_ordering == 'th':
                for jy in range(num_pool_regions):
                    for ix in range(num_pool_regions):
                        x1 = x + ix * row_length
                        x2 = x1 + row_length
                        y1 = y + jy * col_length
                        y2 = y1 + col_length

                        x1 = K.cast(x1, 'int32')
                        x2 = K.cast(x2, 'int32')
                        y1 = K.cast(y1, 'int32')
                        y2 = K.cast(y2, 'int32')

                        x2 = x1 + K.maximum(1,x2-x1)
                        y2 = y1 + K.maximum(1,y2-y1)
                        
                        new_shape = [input_shape[0], input_shape[1],
                                     y2 - y1, x2 - x1]

                        x_crop = img[:, :, y1:y2, x1:x2]
                        xm = K.reshape(x_crop, new_shape)
                        pooled_val = K.max(xm, axis=(2, 3))
                        outputs.append(pooled_val)

            elif self.dim_ordering == 'tf':
                x = K.cast(x, 'int32')
                y = K.cast(y, 'int32')
                w = K.cast(w, 'int32')
                h = K.cast(h, 'int32')

                rs = tf.image.resize_images(img[:, y:y+h, x:x+w, :], (self.pool_size, self.pool_size))
                outputs.append(rs)

        final_output = K.concatenate(outputs, axis=0)
        final_output = K.reshape(final_output, (1, self.num_rois, self.pool_size, self.pool_size, self.nb_channels))

        if self.dim_ordering == 'th':
            final_output = K.permute_dimensions(final_output, (0, 1, 4, 2, 3))
        else:
            final_output = K.permute_dimensions(final_output, (0, 1, 2, 3, 4))

        return final_output

# %% [markdown]
# **roi_helpers.py**

# %%
def calc_iou(R, img_data, C, class_mapping):

    bboxes = img_data['bboxes']
    (width, height) = (img_data['width'], img_data['height'])
    # get image dimensions for resizing
    resized_width, resized_height, _ = data_generators.get_new_img_size(width, height, C.im_size)

    gta = np.zeros((len(bboxes), 4))

    for bbox_num, bbox in enumerate(bboxes):
        # get the GT box coordinates, and resize to account for image resizing
        gta[bbox_num, 0] = int(round(bbox['x1'] * (resized_width / float(width))/C.rpn_stride))
        gta[bbox_num, 1] = int(round(bbox['x2'] * (resized_width / float(width))/C.rpn_stride))
        gta[bbox_num, 2] = int(round(bbox['y1'] * (resized_height / float(height))/C.rpn_stride))
        gta[bbox_num, 3] = int(round(bbox['y2'] * (resized_height / float(height))/C.rpn_stride))

    x_roi = []
    y_class_num = []
    y_class_regr_coords = []
    y_class_regr_label = []

    for ix in range(R.shape[0]):
        (x1, y1, x2, y2) = R[ix, :]
        x1 = int(round(x1))
        y1 = int(round(y1))
        x2 = int(round(x2))
        y2 = int(round(y2))

        best_iou = 0.0
        best_bbox = -1
        for bbox_num in range(len(bboxes)):
            curr_iou = data_generators.iou([gta[bbox_num, 0], gta[bbox_num, 2], gta[bbox_num, 1], gta[bbox_num, 3]], [x1, y1, x2, y2])
            if curr_iou > best_iou:
                best_iou = curr_iou
                best_bbox = bbox_num

        if best_iou < C.classifier_min_overlap:
                continue
        else:
            w = x2 - x1
            h = y2 - y1
            x_roi.append([x1, y1, w, h])

            if C.classifier_min_overlap <= best_iou < C.classifier_max_overlap:
                # hard negative example
                cls_name = 'bg'
            elif C.classifier_max_overlap <= best_iou:
                cls_name = bboxes[best_bbox]['class']
                cxg = (gta[best_bbox, 0] + gta[best_bbox, 1]) / 2.0
                cyg = (gta[best_bbox, 2] + gta[best_bbox, 3]) / 2.0

                cx = x1 + w / 2.0
                cy = y1 + h / 2.0

                tx = (cxg - cx) / float(w)
                ty = (cyg - cy) / float(h)
                tw = np.log((gta[best_bbox, 1] - gta[best_bbox, 0]) / float(w))
                th = np.log((gta[best_bbox, 3] - gta[best_bbox, 2]) / float(h))
            else:
                print('roi = {}'.format(best_iou))
                raise RuntimeError

        class_num = class_mapping[cls_name]
        class_label = len(class_mapping) * [0]
        class_label[class_num] = 1
        y_class_num.append(copy.deepcopy(class_label))
        coords = [0] * 4 * (len(class_mapping) - 1)
        labels = [0] * 4 * (len(class_mapping) - 1)
        if cls_name != 'bg':
            label_pos = 4 * class_num
            sx, sy, sw, sh = C.classifier_regr_std
            coords[label_pos:4+label_pos] = [sx*tx, sy*ty, sw*tw, sh*th]
            labels[label_pos:4+label_pos] = [1, 1, 1, 1]
            y_class_regr_coords.append(copy.deepcopy(coords))
            y_class_regr_label.append(copy.deepcopy(labels))
        else:
            y_class_regr_coords.append(copy.deepcopy(coords))
            y_class_regr_label.append(copy.deepcopy(labels))

    if len(x_roi) == 0:
        return None, None, None

    X = np.array(x_roi)
    Y1 = np.array(y_class_num)
    Y2 = np.concatenate([np.array(y_class_regr_label),np.array(y_class_regr_coords)],axis=1)

    return np.expand_dims(X, axis=0), np.expand_dims(Y1, axis=0), np.expand_dims(Y2, axis=0)

def apply_regr(x, y, w, h, tx, ty, tw, th):
    try:
        cx = x + w/2.
        cy = y + h/2.
        cx1 = tx * w + cx
        cy1 = ty * h + cy
        w1 = math.exp(tw) * w
        h1 = math.exp(th) * h
        x1 = cx1 - w1/2.
        y1 = cy1 - h1/2.
        x1 = int(round(x1))
        y1 = int(round(y1))
        w1 = int(round(w1))
        h1 = int(round(h1))

        return x1, y1, w1, h1

    except ValueError:
        return x, y, w, h
    except OverflowError:
        return x, y, w, h
    except Exception as e:
        print(e)
        return x, y, w, h

def apply_regr_np(X, T):
    try:
        x = X[0, :, :]
        y = X[1, :, :]
        w = X[2, :, :]
        h = X[3, :, :]

        tx = T[0, :, :]
        ty = T[1, :, :]
        tw = T[2, :, :]
        th = T[3, :, :]

        cx = x + w/2.
        cy = y + h/2.
        cx1 = tx * w + cx
        cy1 = ty * h + cy

        w1 = np.exp(tw.astype(np.float64)) * w
        h1 = np.exp(th.astype(np.float64)) * h
        x1 = cx1 - w1/2.
        y1 = cy1 - h1/2.

        x1 = np.round(x1)
        y1 = np.round(y1)
        w1 = np.round(w1)
        h1 = np.round(h1)
        return np.stack([x1, y1, w1, h1])
    except Exception as e:
        print(e)
        return X

def non_max_suppression_fast(boxes, probs, overlap_thresh=0.9, max_boxes=300):
    """
    Eliminating redundant object detection windows with a faster non maximum suppression method
    Greedily select high-scoring detections and skip detections that are significantly covered by 
    a previously selected detection.
    :param boxes: list of boxes 
    :param probs: list of probabilities relatives to the boxes
    """

    # code used from here: http://www.pyimagesearch.com/2015/02/16/faster-non-maximum-suppression-python/
    # if there are no boxes, return an empty list
    if len(boxes) == 0:
        return []

    # grab the coordinates of the bounding boxes
    x1 = boxes[:, 0]
    y1 = boxes[:, 1]
    x2 = boxes[:, 2]
    y2 = boxes[:, 3]

    np.testing.assert_array_less(x1, x2)
    np.testing.assert_array_less(y1, y2)

    # if the bounding boxes integers, convert them to floats --
    # this is important since we'll be doing a bunch of divisions
    if boxes.dtype.kind == "i":
        boxes = boxes.astype("float")

    # initialize the list of picked indexes 
    pick = []

    # calculate the areas
    area = (x2 - x1 + 1) * (y2 - y1 + 1)
    
    # sort the bounding boxes 
    idxs = np.argsort(probs)

    # keep looping while some indexes still remain in the indexes
    # list
    while len(idxs) > 0:
        # grab the last index in the indexes list and add the
        # index value to the list of picked indexes
        last = len(idxs) - 1
        i = idxs[last]
        pick.append(i)

        # find the intersection

        xx1_int = np.maximum(x1[i], x1[idxs[:last]])
        yy1_int = np.maximum(y1[i], y1[idxs[:last]])
        xx2_int = np.minimum(x2[i], x2[idxs[:last]])
        yy2_int = np.minimum(y2[i], y2[idxs[:last]])

        ww_int = np.maximum(0, xx2_int - xx1_int + 0.5)
        hh_int = np.maximum(0, yy2_int - yy1_int + 0.5)

        area_int = ww_int * hh_int

        # find the union
        area_union = area[i] + area[idxs[:last]] - area_int

        # compute the ratio of overlap
        overlap = area_int / (area_union + 1e-6)

        # delete all indexes from the index list that have
        idxs = np.delete(idxs, np.concatenate(([last],
            np.where(overlap > overlap_thresh)[0])))

        if len(pick) >= max_boxes:
            break

    # return only the bounding boxes that were picked using the integer data type
    boxes = boxes[pick].astype("int")
    probs = probs[pick]
    return boxes, probs

import time
def rpn_to_roi(rpn_layer, regr_layer, C, dim_ordering, use_regr=True, max_boxes=300,overlap_thresh=0.9):

    regr_layer = regr_layer / C.std_scaling

    anchor_sizes = C.anchor_box_scales
    anchor_ratios = C.anchor_box_ratios

    assert rpn_layer.shape[0] == 1

    if dim_ordering == 'th':
        (rows,cols) = rpn_layer.shape[2:]

    elif dim_ordering == 'tf':
        (rows, cols) = rpn_layer.shape[1:3]

    curr_layer = 0
    if dim_ordering == 'tf':
        A = np.zeros((4, rpn_layer.shape[1], rpn_layer.shape[2], rpn_layer.shape[3]))
    elif dim_ordering == 'th':
        A = np.zeros((4, rpn_layer.shape[2], rpn_layer.shape[3], rpn_layer.shape[1]))

    for anchor_size in anchor_sizes:
        for anchor_ratio in anchor_ratios:

            anchor_x = (anchor_size * anchor_ratio[0])/C.rpn_stride
            anchor_y = (anchor_size * anchor_ratio[1])/C.rpn_stride
            if dim_ordering == 'th':
                regr = regr_layer[0, 4 * curr_layer:4 * curr_layer + 4, :, :]
            else:
                regr = regr_layer[0, :, :, 4 * curr_layer:4 * curr_layer + 4]
                regr = np.transpose(regr, (2, 0, 1))

            X, Y = np.meshgrid(np.arange(cols),np. arange(rows))

            A[0, :, :, curr_layer] = X - anchor_x/2
            A[1, :, :, curr_layer] = Y - anchor_y/2
            A[2, :, :, curr_layer] = anchor_x
            A[3, :, :, curr_layer] = anchor_y

            if use_regr:
                A[:, :, :, curr_layer] = apply_regr_np(A[:, :, :, curr_layer], regr)

            A[2, :, :, curr_layer] = np.maximum(1, A[2, :, :, curr_layer])
            A[3, :, :, curr_layer] = np.maximum(1, A[3, :, :, curr_layer])
            A[2, :, :, curr_layer] += A[0, :, :, curr_layer]
            A[3, :, :, curr_layer] += A[1, :, :, curr_layer]

            A[0, :, :, curr_layer] = np.maximum(0, A[0, :, :, curr_layer])
            A[1, :, :, curr_layer] = np.maximum(0, A[1, :, :, curr_layer])
            A[2, :, :, curr_layer] = np.minimum(cols-1, A[2, :, :, curr_layer])
            A[3, :, :, curr_layer] = np.minimum(rows-1, A[3, :, :, curr_layer])

            curr_layer += 1

    all_boxes = np.reshape(A.transpose((0, 3, 1,2)), (4, -1)).transpose((1, 0))
    all_probs = rpn_layer.transpose((0, 3, 1, 2)).reshape((-1))

    x1 = all_boxes[:, 0]
    y1 = all_boxes[:, 1]
    x2 = all_boxes[:, 2]
    y2 = all_boxes[:, 3]

    idxs = np.where((x1 - x2 >= 0) | (y1 - y2 >= 0))

    all_boxes = np.delete(all_boxes, idxs, 0)
    all_probs = np.delete(all_probs, idxs, 0)

    result = non_max_suppression_fast(all_boxes, all_probs, overlap_thresh=overlap_thresh, max_boxes=max_boxes)[0]

    return result

# %% [markdown]
# ## YOLOv3
#
# シンプソンズのデータセットをFaster R-CNN以外の手法で学習・推定を行います。YOLOv3\[2\]のKeras実装を使います。
#
# [qqwweee/keras-yolo3: A Keras implementation of YOLOv3 (Tensorflow backend)](https://github.com/qqwweee/keras-yolo3)
#
# \[2\]Jeseph Redmon, Ali Farhadi. YOLOv3: An Incremental Improvement
#
# [https://pjreddie.com/media/files/papers/YOLOv3.pdf](https://pjreddie.com/media/files/papers/YOLOv3.pdf)
#
# Sprint18で使用した実装（再掲）
#
# [lasershow/SimpsonRecognition: Detect and recognize The Simpsons characters using Keras and Faster R-CNN](https://github.com/lasershow/SimpsonRecognition)

# %% [markdown]
# ## 【問題3】学習済みの重みによる推定
#
# 学習済みの重みを使い推定を行う方法がREADME.mdのQuick Startに記載されています。
#
# まずはこの通りにして各自何かしらの画像や動画に対して検出を行ってください。
#
# 出力結果を課題の一部として提出してください。

# %% [markdown]
# <img src="room.png">

# %% [markdown]
# 適当な画像に対して検出。person, bed, pottedplant, clockを検出できた。

# %% [markdown]
# ## 【問題4】学習のためのファイルを作成
#
# 新しいデータ（シンプソンズデータセット）を学習します。README.mdのTrainingを読み、シンプソンズデータセットを学習するために必要なファイルを作成してください。
#
# アノテーションファイルの形式がSprint18で扱った実装のものとは異なっているので、変換する必要があります。

# %%
#ファイルの読み込み
with open('annotation.txt') as f:
    txt = f.readlines()

# %%
#空の辞書と初期値
class_dic = {}
class_num = 0

#ファイルの行数分実行
for i in txt:
    #分割
    data = i.split(',')
    path = data[0] #パス
    annotation = data[1: -1] #座標
    classes = data[-1] #クラス
    
    #クラス名を番号と紐づけで、辞書に
    if classes not in class_dic:
        class_dic[classes] = class_num
        class_num += 1
        
    #アノテーションファイルを作成
    with open('train.txt', 'a') as f_train:
        f_train.write(path + ' ' + ','.join(annotation)  + ',' + str(class_dic[classes]) + '\n')

# %%
#クラスファイルを作成
for i in class_dic.keys():
    with open('classes.txt', 'a') as f_class: 
        f_class.write(i)

# %% [markdown]
# 作成したtrain.txtはkeras_yolo3ファイル内に、classes.txtはkeras_yolo3内のsimpsons_modelファイルに移動。
# github用に、question4ファイルに作成したアノテーションファイルをコピー。

# %% [markdown]
# ## 【問題5】学習
#
# 問題4で作成したファイルを使用して学習してください。実行環境で学習に時間がかかる場合は、学習が行えることを確認するのみで終えて構いません。

# %%
#ディレクトリの移動
# %cd ./keras_yolo3
# Out:
# /Users/yuhisoejima/python/diveintocode-ml/diveintocode-term2/sprint18/keras_yolo3

# %%
# %run convert.py -w yolov3.cfg yolov3.weights simpsons_model/yolo_weights.h5
# Out:
# Using TensorFlow backend.
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# WARNING:tensorflow:From /Users/yuhisoejima/.pyenv/versions/anaconda3-5.3.1/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Parsing section convolutional_1
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section convolutional_2
# conv2d bn leaky (1, 1, 64, 32)
# Parsing section convolutional_3
# conv2d bn leaky (3, 3, 32, 64)
# Parsing section shortcut_0
# Parsing section convolutional_4
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section convolutional_5
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_6
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_1
# Parsing section convolutional_7
# conv2d bn leaky (1, 1, 128, 64)
# Parsing section convolutional_8
# conv2d bn leaky (3, 3, 64, 128)
# Parsing section shortcut_2
# Parsing section convolutional_9
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_10
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_11
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_3
# Parsing section convolutional_12
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_13
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_4
# Parsing section convolutional_14
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_15
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_5
# Parsing section convolutional_16
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_17
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_6
# Parsing section convolutional_18
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_19
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_7
# Parsing section convolutional_20
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_21
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_8
# Parsing section convolutional_22
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_23
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_9
# Parsing section convolutional_24
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_25
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section shortcut_10
# Parsing section convolutional_26
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_27
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_28
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_11
# Parsing section convolutional_29
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_30
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_12
# Parsing section convolutional_31
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_32
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_13
# Parsing section convolutional_33
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_34
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_14
# Parsing section convolutional_35
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_36
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_15
# Parsing section convolutional_37
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_38
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_16
# Parsing section convolutional_39
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_40
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_17
# Parsing section convolutional_41
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_42
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section shortcut_18
# Parsing section convolutional_43
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_44
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_45
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_19
# Parsing section convolutional_46
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_47
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_20
# Parsing section convolutional_48
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_49
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_21
# Parsing section convolutional_50
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_51
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section shortcut_22
# Parsing section convolutional_52
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_53
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_54
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_55
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_56
# conv2d bn leaky (1, 1, 1024, 512)
# Parsing section convolutional_57
# conv2d bn leaky (3, 3, 512, 1024)
# Parsing section convolutional_58
# conv2d    linear (1, 1, 1024, 255)
# Parsing section yolo_0
# Parsing section route_0
# Parsing section convolutional_59
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section upsample_0
# Parsing section route_1
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_1/ResizeNearestNeighbor:0' shape=(?, ?, ?, 256) dtype=float32>, <tf.Tensor 'add_19/add:0' shape=(?, ?, ?, 512) dtype=float32>]
# Parsing section convolutional_60
# conv2d bn leaky (1, 1, 768, 256)
# Parsing section convolutional_61
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_62
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_63
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_64
# conv2d bn leaky (1, 1, 512, 256)
# Parsing section convolutional_65
# conv2d bn leaky (3, 3, 256, 512)
# Parsing section convolutional_66
# conv2d    linear (1, 1, 512, 255)
# Parsing section yolo_1
# Parsing section route_2
# Parsing section convolutional_67
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section upsample_1
# Parsing section route_3
# Concatenating route layers: [<tf.Tensor 'up_sampling2d_2/ResizeNearestNeighbor:0' shape=(?, ?, ?, 128) dtype=float32>, <tf.Tensor 'add_11/add:0' shape=(?, ?, ?, 256) dtype=float32>]
# Parsing section convolutional_68
# conv2d bn leaky (1, 1, 384, 128)
# Parsing section convolutional_69
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_70
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_71
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_72
# conv2d bn leaky (1, 1, 256, 128)
# Parsing section convolutional_73
# conv2d bn leaky (3, 3, 128, 256)
# Parsing section convolutional_74
# conv2d    linear (1, 1, 256, 255)
# Parsing section yolo_2
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 3 864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, None, None, 3 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, None, None, 3 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, None, None, 3 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 18432       zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, None, None, 6 256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 3 2048        leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, None, None, 3 128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, None, None, 3 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 6 18432       leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, None, None, 6 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, None, None, 6 0           leaky_re_lu_2[0][0]
#                                                                  leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, None, None, 6 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 1 73728       zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, None, None, 1 512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 6 8192        leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, None, None, 6 256         conv2d_6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 1 73728       leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, None, None, 1 512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, None, None, 1 0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 6 8192        add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, None, None, 6 256         conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, None, None, 6 0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 1 73728       leaky_re_lu_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, None, None, 1 512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, None, None, 1 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, None, None, 1 0           add_2[0][0]
#                                                                  leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, None, None, 1 0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 2 294912      zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, None, None, 2 1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, None, None, 1 512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, None, None, 2 1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, None, None, 2 0           leaky_re_lu_10[0][0]
#                                                                  leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 1 32768       add_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, None, None, 1 512         conv2d_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, None, None, 2 1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, None, None, 2 0           add_4[0][0]
#                                                                  leaky_re_lu_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 1 32768       add_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, None, None, 1 512         conv2d_15[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, None, None, 2 1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, None, None, 2 0           add_5[0][0]
#                                                                  leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 32768       add_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, None, None, 1 512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, None, None, 2 1024        conv2d_18[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, None, None, 2 0           add_6[0][0]
#                                                                  leaky_re_lu_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 1 32768       add_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, None, None, 1 512         conv2d_19[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, None, None, 2 1024        conv2d_20[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, None, None, 2 0           add_7[0][0]
#                                                                  leaky_re_lu_20[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 1 32768       add_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, None, None, 1 512         conv2d_21[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, None, None, 2 1024        conv2d_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, None, None, 2 0           add_8[0][0]
#                                                                  leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 1 32768       add_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, None, None, 1 512         conv2d_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, None, None, 2 1024        conv2d_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, None, None, 2 0           add_9[0][0]
#                                                                  leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 1 32768       add_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, None, None, 1 512         conv2d_25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, None, None, 2 1024        conv2d_26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, None, None, 2 0           add_10[0][0]
#                                                                  leaky_re_lu_26[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, None, None, 2 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 5 1179648     zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, None, None, 5 2048        conv2d_27[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, None, None, 2 1024        conv2d_28[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, None, None, 5 2048        conv2d_29[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, None, None, 5 0           leaky_re_lu_27[0][0]
#                                                                  leaky_re_lu_29[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, None, None, 2 131072      add_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, None, None, 2 1024        conv2d_30[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, None, None, 5 2048        conv2d_31[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, None, None, 5 0           add_12[0][0]
#                                                                  leaky_re_lu_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, None, None, 2 131072      add_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, None, None, 2 1024        conv2d_32[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, None, None, 5 2048        conv2d_33[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, None, None, 5 0           add_13[0][0]
#                                                                  leaky_re_lu_33[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, None, None, 2 131072      add_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, None, None, 2 1024        conv2d_34[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, None, None, 5 2048        conv2d_35[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, None, None, 5 0           add_14[0][0]
#                                                                  leaky_re_lu_35[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, None, None, 2 131072      add_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, None, None, 2 1024        conv2d_36[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, None, None, 5 2048        conv2d_37[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_37 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, None, None, 5 0           add_15[0][0]
#                                                                  leaky_re_lu_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, None, None, 2 131072      add_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, None, None, 2 1024        conv2d_38[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_38 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, None, None, 5 2048        conv2d_39[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_39 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, None, None, 5 0           add_16[0][0]
#                                                                  leaky_re_lu_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, None, None, 2 131072      add_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, None, None, 2 1024        conv2d_40[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_40 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, None, None, 5 2048        conv2d_41[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_41 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, None, None, 5 0           add_17[0][0]
#                                                                  leaky_re_lu_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, None, None, 2 131072      add_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, None, None, 2 1024        conv2d_42[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_42 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, None, None, 5 2048        conv2d_43[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_43 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, None, None, 5 0           add_18[0][0]
#                                                                  leaky_re_lu_43[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, None, None, 5 0           add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, None, None, 1 4718592     zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, None, None, 1 4096        conv2d_44[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_44 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, None, None, 5 2048        conv2d_45[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_45 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, None, None, 1 4096        conv2d_46[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_46 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, None, None, 1 0           leaky_re_lu_44[0][0]
#                                                                  leaky_re_lu_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, None, None, 5 524288      add_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, None, None, 5 2048        conv2d_47[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_47 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, None, None, 1 4096        conv2d_48[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_48 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, None, None, 1 0           add_20[0][0]
#                                                                  leaky_re_lu_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, None, None, 5 524288      add_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, None, None, 5 2048        conv2d_49[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_49 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, None, None, 1 4096        conv2d_50[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_50 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, None, None, 1 0           add_21[0][0]
#                                                                  leaky_re_lu_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, None, None, 5 524288      add_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, None, None, 5 2048        conv2d_51[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_51 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, None, None, 1 4096        conv2d_52[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_52 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, None, None, 1 0           add_22[0][0]
#                                                                  leaky_re_lu_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, None, None, 5 524288      add_23[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, None, None, 5 2048        conv2d_53[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_53 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, None, None, 1 4096        conv2d_54[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_54 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, None, None, 5 2048        conv2d_55[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_55 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, None, None, 1 4096        conv2d_56[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_56 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, None, None, 5 524288      leaky_re_lu_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, None, None, 5 2048        conv2d_57[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_57 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, None, None, 2 1024        conv2d_60[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_59 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, None, None, 2 0           leaky_re_lu_59[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 7 0           up_sampling2d_1[0][0]
#                                                                  add_19[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, None, None, 2 196608      concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, None, None, 2 1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_60 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, None, None, 5 2048        conv2d_62[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_61 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, None, None, 2 1024        conv2d_63[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_62 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, None, None, 5 2048        conv2d_64[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_63 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, None, None, 2 131072      leaky_re_lu_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, None, None, 2 1024        conv2d_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_64 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, None, None, 1 512         conv2d_68[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_66 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, None, None, 1 0           leaky_re_lu_66[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 3 0           up_sampling2d_2[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, None, None, 1 49152       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, None, None, 1 512         conv2d_69[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_67 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, None, None, 2 1024        conv2d_70[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_68 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, None, None, 1 512         conv2d_71[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_69 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, None, None, 2 1024        conv2d_72[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_70 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, None, None, 1 32768       leaky_re_lu_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, None, None, 1 512         conv2d_73[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_71 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, None, None, 1 4718592     leaky_re_lu_57[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, None, None, 5 1179648     leaky_re_lu_64[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, None, None, 2 294912      leaky_re_lu_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, None, None, 1 4096        conv2d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, None, None, 5 2048        conv2d_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, None, None, 2 1024        conv2d_74[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_58 (LeakyReLU)      (None, None, None, 1 0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_65 (LeakyReLU)      (None, None, None, 5 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_72 (LeakyReLU)      (None, None, None, 2 0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, None, None, 2 261375      leaky_re_lu_58[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, None, None, 2 130815      leaky_re_lu_65[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, None, None, 2 65535       leaky_re_lu_72[0][0]
# ==================================================================================================
# Total params: 62,001,757
# Trainable params: 61,949,149
# Non-trainable params: 52,608
# __________________________________________________________________________________________________
# None
# Saved Keras weights to simpsons_model/yolo_weights.h5
# Read 62001757 of 62001757.0 from Darknet weights.

# %%
#学習
# %run train.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Create YOLOv3 model with 9 anchors and 18 classes.
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_59 due to mismatch in shape ((1, 1, 1024, 69) vs (255, 1024, 1, 1)).
#   weight_values[i].shape))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_59 due to mismatch in shape ((69,) vs (255,)).
#   weight_values[i].shape))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_67 due to mismatch in shape ((1, 1, 512, 69) vs (255, 512, 1, 1)).
#   weight_values[i].shape))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_67 due to mismatch in shape ((69,) vs (255,)).
#   weight_values[i].shape))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_75 due to mismatch in shape ((1, 1, 256, 69) vs (255, 256, 1, 1)).
#   weight_values[i].shape))
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/keras/engine/saving.py:1140: UserWarning: Skipping loading of weights for layer conv2d_75 due to mismatch in shape ((69,) vs (255,)).
#   weight_values[i].shape))
# Load weights simpsons_model/yolo_weights.h5.
# Freeze the first 249 layers of total 252 layers.
# Train on 14201 samples, val on 1577 samples, with batch size 32.
# Epoch 1/3
# 443/443 [==============================] - 792s 2s/step - loss: 270.2099 - val_loss: 35.3936
# Epoch 2/3
# 443/443 [==============================] - 760s 2s/step - loss: 30.1832 - val_loss: 25.2587
# Epoch 3/3
# 442/443 [============================>.] - ETA: 1s - loss: 24.1407

# %% [markdown]
# 途中でdead kernelとなったため終了。学習ができていることは確認できた。

# %%
#ディレクトリを戻る
# %cd -
